# %% [markdown]
# #Mastografías en México de 2013 a 2023

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Mastografias en mexico

# %%
import pandas as pd

# Crear un DataFrame vacío con columnas específicas
df = pd.DataFrame(columns=['entidad', 'resultado', 'edad', 'año'])

# Ver el DataFrame vacío
print(df)

# Guardar el DataFrame vacío como CSV (opcional)
df.to_csv('/content/drive/MyDrive/Cancer de mama/nuevo_archivo.csv', index=False)
df
# Out:
# Empty DataFrame
# Columns: [entidad, resultado, edad, año]
# Index: []
# Empty DataFrame
# Columns: [entidad, resultado, edad, año]
# Index: []

# %%
import pandas as pd

# Ruta del archivo en Google Drive
mastografias_13 = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografias 2013.csv'

# Cargar el archivo CSV
df = pd.read_csv(mastografias_13, encoding='latin1')  # Ajustar encoding si es necesario

# Ver los elementos de la fila 0
fila_0 = df.iloc[0]
print(fila_0)
# Out:
# Mastografías 2013                 Clave Entidad
# Unnamed: 1                              Entidad
# Unnamed: 2                   Clave Jurisdicción
# Unnamed: 3                         Jurisdicción
# Unnamed: 4                      Clave Municipio
# Unnamed: 5                            Municipio
# Unnamed: 6                                 Edad
# Unnamed: 7                     Fecha Toma Masto
# Unnamed: 8           Fecha Interpretación Masto
# Unnamed: 9                            Resultado
# Name: 0, dtype: object
# <ipython-input-39-264554ec6b3e>:7: DtypeWarning: Columns (0,2,4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(mastografias_13, encoding='latin1')  # Ajustar encoding si es necesario

# %%
import pandas as pd

# Ruta del archivo en Google Drive
mastografias_13 = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografias 2013.csv'

# Cargar el archivo CSV
df_original = pd.read_csv(mastografias_13, encoding='latin1')

# Seleccionar los elementos de las columnas y omitir la primera fila
entidad = df_original['Unnamed: 1'].iloc[1:].reset_index(drop=True)
resultado = df_original['Unnamed: 9'].iloc[1:].reset_index(drop=True)
edad = df_original['Unnamed: 6'].iloc[1:].reset_index(drop=True)

# Crear un nuevo DataFrame con las columnas requeridas
nuevo_df = pd.DataFrame({
    'entidad': entidad,
    'resultado': resultado,
    'edad': edad,
    'año': 2013  # Rellenar la columna 'año' con 2013
})



# Guardar el nuevo DataFrame como CSV en Google Drive
nuevo_df.to_csv('/content/drive/MyDrive/Cancer de mama/nuevo_archivo_2013.csv', index=False)

# Verificar el nuevo DataFrame
nuevo_df.head()
# Out:
# <ipython-input-43-045fbbc60ec9>:7: DtypeWarning: Columns (0,2,4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_original = pd.read_csv(mastografias_13, encoding='latin1')
#           entidad              resultado edad   año
# 0  Aguascalientes  Probablemente Benigna   52  2013
# 1  Aguascalientes               Negativa   48  2013
# 2  Aguascalientes               Negativa   48  2013
# 3  Aguascalientes               Negativa   69  2013
# 4  Aguascalientes               Negativa   44  2013

# %%
import pandas as pd

# Ruta del archivo en tu Google Drive
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2018.xlsx - Mastografías.csv'

# Intentar leer el archivo con una codificación alternativa
df_prueba = pd.read_csv(file_path, encoding='latin1')  # Prueba con 'latin1' o 'ISO-8859-1'
df_prueba.head()
# Out:
# <ipython-input-20-2161a7c13b4b>:7: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_prueba = pd.read_csv(file_path, encoding='latin1')  # Prueba con 'latin1' o 'ISO-8859-1'
#   MastografÃ­as 2018      Unnamed: 1 Unnamed: 2
# 0      Clave Entidad         Entidad  Resultado
# 1                 01  Aguascalientes    Benigna
# 2                 01  Aguascalientes    Benigna
# 3                 01  Aguascalientes    Benigna
# 4                 01  Aguascalientes    Benigna

# %%
import pandas as pd

# Cargar el DataFrame del archivo ya existente de 2013
antiguo_df = pd.read_csv('/content/drive/MyDrive/Cancer de mama/nuevo_archivo_2013_2016.csv')

# Ruta del archivo de 2014 en Google Drive
mastografias_nuevo = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2017.csv'

# Cargar el archivo CSV de 2014
df = pd.read_csv(mastografias_nuevo, encoding='latin1')

# Seleccionar los elementos de las columnas y omitir la primera fila
entidad = df['Unnamed: 1'].iloc[1:].reset_index(drop=True)
resultado = df['Unnamed: 9'].iloc[1:].reset_index(drop=True)
edad = df['Unnamed: 6'].iloc[1:].reset_index(drop=True)

# Crear un nuevo DataFrame con las columnas requeridas para 2014
nuevo_df = pd.DataFrame({
    'entidad': entidad,
    'resultado': resultado,
    'edad': edad,
    'año': 2017  # Rellenar la columna 'año' con 2014
})

# Concatenar los datos de 2013 y 2014
df_combinado = pd.concat([antiguo_df, nuevo_df], ignore_index=True)

# Guardar el DataFrame combinado como un nuevo CSV en Google Drive
df_combinado.to_csv('/content/drive/MyDrive/Cancer de mama/nuevo_archivo_2013_2017.csv', index=False)

# Verificar el DataFrame combinado
df_combinado.head()
# Out:
# <ipython-input-18-c674ae8469fe>:10: DtypeWarning: Columns (0,2,4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(mastografias_nuevo, encoding='latin1')
#           entidad              resultado edad   año
# 0  Aguascalientes  Probablemente Benigna   52  2013
# 1  Aguascalientes               Negativa   48  2013
# 2  Aguascalientes               Negativa   48  2013
# 3  Aguascalientes               Negativa   69  2013
# 4  Aguascalientes               Negativa   44  2013

# %%
print(len(df_combinado))
print(df_combinado['año'].iloc[-1])
# Out:
# 4261917
# 2017

# %%
import pandas as pd

# Ruta del archivo CSV
archivo_path = '/content/drive/MyDrive/Cancer de mama/nuevo_archivo_2013_2017.csv'

# Cargar el archivo CSV
df_cargado = pd.read_csv(archivo_path)

# Verificar las primeras filas del DataFrame
df_cargado
# Out:
#                 entidad              resultado  edad   año
# 0        Aguascalientes  Probablemente Benigna    52  2013
# 1        Aguascalientes               Negativa    48  2013
# 2        Aguascalientes               Negativa    48  2013
# 3        Aguascalientes               Negativa    69  2013
# 4        Aguascalientes               Negativa    44  2013
# ...                 ...                    ...   ...   ...
# 4261912       Zacatecas                Benigna    47  2017
# 4261913       Zacatecas   Evaluación Adicional    49  2017
# 4261914       Zacatecas                Benigna    57  2017
# 4261915       Zacatecas   Evaluación Adicional    67  2017
# 4261916       Zacatecas                Benigna    44  2017
#
# [4261917 rows x 4 columns]

# %%
# Obtener los valores únicos de la columna 'resultado'
valores_unicos = df_cargado['resultado'].unique()

# Mostrar los valores únicos
print(valores_unicos)
# Out:
# ['Probablemente Benigna' 'Negativa' 'Benigna' 'Anormalidad Sospechosa'
#  'Altamente Sugestiva a Malignidad' 'Evaluación Adicional' nan
#  'Riesgo Moderado de Malignidad' 'Baja Sospecha de Malignidad'
#  'Riesgo Intermedio de Malignidad']

# %%
# Calcular el promedio de edad para cada resultado (1 a 9)
promedios_edad = df_cargado.groupby('resultado')['edad'].mean()

# Mostrar los promedios
print(promedios_edad)
# Out:
# resultado
# Altamente Sugestiva a Malignidad    51.566308
# Anormalidad Sospechosa              50.340199
# Baja Sospecha de Malignidad         50.278418
# Benigna                             50.941807
# Evaluación Adicional                48.220702
# Negativa                            49.946795
# Probablemente Benigna               49.380469
# Riesgo Intermedio de Malignidad     50.917949
# Riesgo Moderado de Malignidad       51.763456
# Name: edad, dtype: float64

# %%
# Calcular el promedio de edad y la cantidad de elementos para cada valor de resultado
estadisticas = df_cargado.groupby('resultado')['edad'].agg(['mean', 'count']).reset_index()

# Renombrar las columnas para mayor claridad
estadisticas.columns = ['resultado', 'promedio_edad', 'cantidad']

# Mostrar el resultado
print(estadisticas)
# Out:
#                           resultado  promedio_edad  cantidad
# 0  Altamente Sugestiva a Malignidad      51.566308      9011
# 1            Anormalidad Sospechosa      50.340199     24762
# 2       Baja Sospecha de Malignidad      50.278418      1821
# 3                           Benigna      50.941807   3066617
# 4              Evaluación Adicional      48.220702    281678
# 5                          Negativa      49.946795    705322
# 6             Probablemente Benigna      49.380469    170608
# 7   Riesgo Intermedio de Malignidad      50.917949      1365
# 8     Riesgo Moderado de Malignidad      51.763456       706

# %%
# Ruta al archivo en Drive
ruta_archivo = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2023.xlsx - Mastografías.csv'

# Cargar el CSV, omitiendo la primera fila
df = pd.read_csv(ruta_archivo,skiprows=1)

# Renombrar las columnas
df = df.rename(columns={'Entidad': 'entidad', 'Resultado': 'resultado'})
df['edad'] = np.nan
df['año'] = 2023
df
# Out:
#                entidad resultado  edad   año
# 0       Aguascalientes   Benigna   NaN  2023
# 1       Aguascalientes   Benigna   NaN  2023
# 2       Aguascalientes   Benigna   NaN  2023
# 3       Aguascalientes   Benigna   NaN  2023
# 4       Aguascalientes   Benigna   NaN  2023
# ...                ...       ...   ...   ...
# 530750       Zacatecas   Benigna   NaN  2023
# 530751       Zacatecas   Benigna   NaN  2023
# 530752       Zacatecas   Benigna   NaN  2023
# 530753       Zacatecas  Negativa   NaN  2023
# 530754       Zacatecas   Benigna   NaN  2023
#
# [530755 rows x 4 columns]

# %%
# Ruta al archivo en Drive
ruta_archivo = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2020.csv'

# Cargar el CSV, omitiendo la primera fila
df = pd.read_csv(ruta_archivo)
df = df.drop(columns=['año'])
# Añadir la columna 'edad' con valores nulos
df['edad'] = np.nan
df['año'] = 2020
df
# Out:
#                entidad             resultado  edad   año
# 0       Aguascalientes               Benigna   NaN  2020
# 1       Aguascalientes               Benigna   NaN  2020
# 2       Aguascalientes               Benigna   NaN  2020
# 3       Aguascalientes               Benigna   NaN  2020
# 4       Aguascalientes               Benigna   NaN  2020
# ...                ...                   ...   ...   ...
# 324581       Zacatecas  Evaluación Adicional   NaN  2020
# 324582       Zacatecas              Negativa   NaN  2020
# 324583       Zacatecas              Negativa   NaN  2020
# 324584       Zacatecas  Evaluación Adicional   NaN  2020
# 324585       Zacatecas               Benigna   NaN  2020
#
# [324586 rows x 4 columns]

# %%
# Ruta al archivo en Drive
ruta_archivo = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2019.csv'

# Cargar el CSV, omitiendo la primera fila
df = pd.read_csv(ruta_archivo, skiprows=1)


# Eliminar columnas
df = df.drop(columns=['Clave Entidad'])
df = df.drop(columns=['Clave Jurisdicción'])
df = df.drop(columns=['Jurisdicción'])
df = df.drop(columns=['Clave Municipio'])
df = df.drop(columns=['Municipio'])
df = df.drop(columns=['Fecha Toma Masto'])
df = df.drop(columns=['Fecha Interpretación Masto'])

# Renombrar las columnas
df = df.rename(columns={'Entidad': 'entidad','Edad': 'edad', 'Resultado': 'resultado'})

df
# Out:
#                entidad  edad             resultado
# 0       Aguascalientes    45               Benigna
# 1       Aguascalientes    55               Benigna
# 2       Aguascalientes    61               Benigna
# 3       Aguascalientes    60               Benigna
# 4       Aguascalientes    52               Benigna
# ...                ...   ...                   ...
# 790713       Zacatecas    55  Evaluación Adicional
# 790714       Zacatecas    62               Benigna
# 790715       Zacatecas    60  Evaluación Adicional
# 790716       Zacatecas    59               Benigna
# 790717       Zacatecas    43  Evaluación Adicional
#
# [790718 rows x 3 columns]

# %%
import pandas as pd
import numpy as np

# Ruta al archivo en Drive
ruta_archivo = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2019.csv'

# Cargar el CSV, omitiendo la primera fila
df = pd.read_csv(ruta_archivo, skiprows=1)

# Eliminar la columna 'clave de entidad'
df = df.drop(columns=['Clave Entidad'])

# Renombrar las columnas
df = df.rename(columns={'Entidad': 'entidad', 'Resultado': 'resultado'})

# Añadir la columna 'edad' con valores nulos
df['edad'] = np.nan

# Añadir la columna 'año' con el valor 2018
df['año'] = 2018

df
# Out:
#                entidad  Clave Jurisdicción        Jurisdicción  \
# 0       Aguascalientes                   1      Aguascalientes
# 1       Aguascalientes                   1      Aguascalientes
# 2       Aguascalientes                   1      Aguascalientes
# 3       Aguascalientes                   1      Aguascalientes
# 4       Aguascalientes                   1      Aguascalientes
# ...                ...                 ...                 ...
# 790713       Zacatecas                   7  Concepción Del Oro
# 790714       Zacatecas                   7  Concepción Del Oro
# 790715       Zacatecas                   7  Concepción Del Oro
# 790716       Zacatecas                   7  Concepción Del Oro
# 790717       Zacatecas                   7  Concepción Del Oro
#
#         Clave Municipio       Municipio  Edad Fecha Toma Masto  \
# 0                     1  AGUASCALIENTES    45        11/4/2019
# 1                     1  AGUASCALIENTES    55        11/3/2019
# ...

# %%
# Reemplazamos los valores de 'edad' donde 'resultado' es 'Benigna'
df.loc[df['resultado'] == 'Benigna', 'edad'] = 51
df.loc[df['resultado'] == 'Probablemente Benigna', 'edad'] = 49
df.loc[df['resultado'] == 'Altamente Sugestiva a Malignidad', 'edad'] = 52
df.loc[df['resultado'] == 'Evaluación Adicional', 'edad'] = 48
df.loc[df['resultado'] == 'Riesgo Intermedio de Malignidad', 'edad'] = 51
df.loc[df['resultado'] == 'Riesgo Moderado de Malignidad', 'edad'] = 52
df.loc[df['resultado'] == 'Negativa', 'edad'] = 50
df.loc[df['resultado'] == 'Baja Sospecha de Malignidad', 'edad'] = 50
df.loc[df['resultado'] == 'Anormalidad Sospechosa', 'edad'] = 50

# Verificamos si hay valores NaN en el DataFrame
nan_values = df.isna().sum()

# Mostramos la cantidad de NaNs por columna
print(nan_values)

# Si no hay NaNs en ninguna columna, el resultado debería ser todo ceros
if nan_values.sum() == 0:
    print("No hay valores NaN en el DataFrame.")
else:
    print("Hay valores NaN en el DataFrame.")

df
# Out:
# entidad      0
# resultado    0
# edad         0
# año          0
# dtype: int64
# No hay valores NaN en el DataFrame.
#                entidad resultado  edad   año
# 0       Aguascalientes   Benigna  51.0  2023
# 1       Aguascalientes   Benigna  51.0  2023
# 2       Aguascalientes   Benigna  51.0  2023
# 3       Aguascalientes   Benigna  51.0  2023
# 4       Aguascalientes   Benigna  51.0  2023
# ...                ...       ...   ...   ...
# 530750       Zacatecas   Benigna  51.0  2023
# 530751       Zacatecas   Benigna  51.0  2023
# 530752       Zacatecas   Benigna  51.0  2023
# 530753       Zacatecas  Negativa  50.0  2023
# 530754       Zacatecas   Benigna  51.0  2023
#
# [530755 rows x 4 columns]

# %%
# Especifica la ruta donde quieres guardar el archivo en tu Google Drive
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2023.csv'

# Guarda el DataFrame como un archivo CSV
df.to_csv(file_path, index=False)

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2023.csv'
# Cargar el CSV, omitiendo la primera fila
df = pd.read_csv(file_path)
df
# Out:
#                entidad resultado  edad   año
# 0       Aguascalientes   Benigna  51.0  2023
# 1       Aguascalientes   Benigna  51.0  2023
# 2       Aguascalientes   Benigna  51.0  2023
# 3       Aguascalientes   Benigna  51.0  2023
# 4       Aguascalientes   Benigna  51.0  2023
# ...                ...       ...   ...   ...
# 530750       Zacatecas   Benigna  51.0  2023
# 530751       Zacatecas   Benigna  51.0  2023
# 530752       Zacatecas   Benigna  51.0  2023
# 530753       Zacatecas  Negativa  50.0  2023
# 530754       Zacatecas   Benigna  51.0  2023
#
# [530755 rows x 4 columns]

# %%
# Añadir la columna 'año' con el valor 2018
df['año'] = 2019
df
# Out:
#                entidad  edad             resultado   año
# 0       Aguascalientes    45               Benigna  2019
# 1       Aguascalientes    55               Benigna  2019
# 2       Aguascalientes    61               Benigna  2019
# 3       Aguascalientes    60               Benigna  2019
# 4       Aguascalientes    52               Benigna  2019
# ...                ...   ...                   ...   ...
# 790713       Zacatecas    55  Evaluación Adicional  2019
# 790714       Zacatecas    62               Benigna  2019
# 790715       Zacatecas    60  Evaluación Adicional  2019
# 790716       Zacatecas    59               Benigna  2019
# 790717       Zacatecas    43  Evaluación Adicional  2019
#
# [790718 rows x 4 columns]

# %%
# Obtener los valores únicos de la columna 'resultado'
valores_unicos = df['resultado'].unique()

# Mostrar los valores únicos
print(valores_unicos)
# Out:
# ['Benigna' 'Probablemente Benigna' 'Altamente Sugestiva a Malignidad'
#  'Evaluación Adicional' 'Riesgo Intermedio de Malignidad'
#  'Riesgo Moderado de Malignidad' 'Negativa' 'Baja Sospecha de Malignidad'
#  'Anormalidad Sospechosa']

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/nuevo_archivo_2013_2017.csv'
# Cargar el CSV, omitiendo la primera fila
df = pd.read_csv(file_path)
df
# Out:
#                 entidad              resultado  edad   año
# 0        Aguascalientes  Probablemente Benigna    52  2013
# 1        Aguascalientes               Negativa    48  2013
# 2        Aguascalientes               Negativa    48  2013
# 3        Aguascalientes               Negativa    69  2013
# 4        Aguascalientes               Negativa    44  2013
# ...                 ...                    ...   ...   ...
# 4261912       Zacatecas                Benigna    47  2017
# 4261913       Zacatecas   Evaluación Adicional    49  2017
# 4261914       Zacatecas                Benigna    57  2017
# 4261915       Zacatecas   Evaluación Adicional    67  2017
# 4261916       Zacatecas                Benigna    44  2017
#
# [4261917 rows x 4 columns]

# %%
print(len(df))
print(df['año'].iloc[-1])
# Out:
# 4261917
# 2017

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2018.csv'
# Cargar el CSV, omitiendo la primera fila
df_18 = pd.read_csv(file_path)
df_18
# Out:
#                entidad resultado  edad   año
# 0       Aguascalientes   Benigna  51.0  2018
# 1       Aguascalientes   Benigna  51.0  2018
# 2       Aguascalientes   Benigna  51.0  2018
# 3       Aguascalientes   Benigna  51.0  2018
# 4       Aguascalientes   Benigna  51.0  2018
# ...                ...       ...   ...   ...
# 816899       Zacatecas  Negativa  50.0  2018
# 816900       Zacatecas  Negativa  50.0  2018
# 816901       Zacatecas   Benigna  51.0  2018
# 816902       Zacatecas   Benigna  51.0  2018
# 816903       Zacatecas  Negativa  50.0  2018
#
# [816904 rows x 4 columns]

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2019.csv'
# Cargar el CSV, omitiendo la primera fila
df_19 = pd.read_csv(file_path)


# Reordenar las columnas
df_19 = df_19[['entidad', 'resultado', 'edad', 'año']]

df_19
# Out:
#                entidad             resultado  edad   año
# 0       Aguascalientes               Benigna    45  2019
# 1       Aguascalientes               Benigna    55  2019
# 2       Aguascalientes               Benigna    61  2019
# 3       Aguascalientes               Benigna    60  2019
# 4       Aguascalientes               Benigna    52  2019
# ...                ...                   ...   ...   ...
# 790713       Zacatecas  Evaluación Adicional    55  2019
# 790714       Zacatecas               Benigna    62  2019
# 790715       Zacatecas  Evaluación Adicional    60  2019
# 790716       Zacatecas               Benigna    59  2019
# 790717       Zacatecas  Evaluación Adicional    43  2019
#
# [790718 rows x 4 columns]

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2020.csv'
# Cargar el CSV, omitiendo la primera fila
df_20 = pd.read_csv(file_path)
df_20
# Out:
#                entidad             resultado  edad   año
# 0       Aguascalientes               Benigna  51.0  2020
# 1       Aguascalientes               Benigna  51.0  2020
# 2       Aguascalientes               Benigna  51.0  2020
# 3       Aguascalientes               Benigna  51.0  2020
# 4       Aguascalientes               Benigna  51.0  2020
# ...                ...                   ...   ...   ...
# 324581       Zacatecas  Evaluación Adicional  48.0  2020
# 324582       Zacatecas              Negativa  50.0  2020
# 324583       Zacatecas              Negativa  50.0  2020
# 324584       Zacatecas  Evaluación Adicional  48.0  2020
# 324585       Zacatecas               Benigna  51.0  2020
#
# [324586 rows x 4 columns]

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2021.csv'
# Cargar el CSV, omitiendo la primera fila
df_21 = pd.read_csv(file_path)
df_21
# Out:
#                entidad              resultado  edad   año
# 0       Aguascalientes  Probablemente Benigna  49.0  2021
# 1       Aguascalientes                Benigna  51.0  2021
# 2       Aguascalientes                Benigna  51.0  2021
# 3       Aguascalientes                Benigna  51.0  2021
# 4       Aguascalientes                Benigna  51.0  2021
# ...                ...                    ...   ...   ...
# 420942       Zacatecas  Probablemente Benigna  49.0  2021
# 420943       Zacatecas                Benigna  51.0  2021
# 420944       Zacatecas                Benigna  51.0  2021
# 420945       Zacatecas                Benigna  51.0  2021
# 420946       Zacatecas   Evaluación Adicional  48.0  2021
#
# [420947 rows x 4 columns]

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2022.csv'
# Cargar el CSV, omitiendo la primera fila
df_22 = pd.read_csv(file_path)
df_22
# Out:
#                entidad resultado  edad   año
# 0       Aguascalientes   Benigna  51.0  2022
# 1       Aguascalientes   Benigna  51.0  2022
# 2       Aguascalientes   Benigna  51.0  2022
# 3       Aguascalientes   Benigna  51.0  2022
# 4       Aguascalientes   Benigna  51.0  2022
# ...                ...       ...   ...   ...
# 577916       Zacatecas   Benigna  51.0  2022
# 577917       Zacatecas   Benigna  51.0  2022
# 577918       Zacatecas   Benigna  51.0  2022
# 577919       Zacatecas   Benigna  51.0  2022
# 577920       Zacatecas   Benigna  51.0  2022
#
# [577921 rows x 4 columns]

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2023.csv'
# Cargar el CSV, omitiendo la primera fila
df_23 = pd.read_csv(file_path)
df_23
# Out:
#                entidad resultado  edad   año
# 0       Aguascalientes   Benigna  51.0  2023
# 1       Aguascalientes   Benigna  51.0  2023
# 2       Aguascalientes   Benigna  51.0  2023
# 3       Aguascalientes   Benigna  51.0  2023
# 4       Aguascalientes   Benigna  51.0  2023
# ...                ...       ...   ...   ...
# 530750       Zacatecas   Benigna  51.0  2023
# 530751       Zacatecas   Benigna  51.0  2023
# 530752       Zacatecas   Benigna  51.0  2023
# 530753       Zacatecas  Negativa  50.0  2023
# 530754       Zacatecas   Benigna  51.0  2023
#
# [530755 rows x 4 columns]

# %%
# Añadir las filas de df2 a df1
df_combined = pd.concat([df, df_18,df_19,df_20,df_21,df_22,df_23], ignore_index=True)
df_combined
# Out:
#                  entidad              resultado  edad   año
# 0         Aguascalientes  Probablemente Benigna  52.0  2013
# 1         Aguascalientes               Negativa  48.0  2013
# 2         Aguascalientes               Negativa  48.0  2013
# 3         Aguascalientes               Negativa  69.0  2013
# 4         Aguascalientes               Negativa  44.0  2013
# ...                  ...                    ...   ...   ...
# 11194942       Zacatecas                Benigna  51.0  2023
# 11194943       Zacatecas                Benigna  51.0  2023
# 11194944       Zacatecas                Benigna  51.0  2023
# 11194945       Zacatecas               Negativa  50.0  2023
# 11194946       Zacatecas                Benigna  51.0  2023
#
# [11194947 rows x 4 columns]

# %%
# Especifica la ruta donde quieres guardar el archivo en tu Google Drive
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2013 - 2023.csv'

# Guarda el DataFrame como un archivo CSV
df_combined.to_csv(file_path, index=False)

# %%
df_combined
# Convertir la columna 'edad' a tipo int
df_combined['edad'] = df_combined['edad'].astype(int)

# %%
df = pd.read_csv(file_path)
df
# Out:
#                  entidad              resultado  edad   año
# 0         Aguascalientes  Probablemente Benigna    52  2013
# 1         Aguascalientes               Negativa    48  2013
# 2         Aguascalientes               Negativa    48  2013
# 3         Aguascalientes               Negativa    69  2013
# 4         Aguascalientes               Negativa    44  2013
# ...                  ...                    ...   ...   ...
# 11194942       Zacatecas                Benigna    51  2023
# 11194943       Zacatecas                Benigna    51  2023
# 11194944       Zacatecas                Benigna    51  2023
# 11194945       Zacatecas               Negativa    50  2023
# 11194946       Zacatecas                Benigna    51  2023
#
# [11194947 rows x 4 columns]

# %%
count_by_year
# Out:
# año
# 2013    1580128
# 2014    1633426
# 2015    1889610
# 2016    1710636
# 2017    1710034
# 2018     816904
# 2020     324586
# 2021     420947
# 2022     577921
# 2023     530755
# Name: count, dtype: int64

# %%
# Contar cuántas veces aparece cada año
count_by_year = df['año'].value_counts().sort_index()

# Graficar
plt.figure(figsize=(8, 6))
count_by_year.plot(kind='bar', color='skyblue')
plt.title('Número de Filas por Año')
plt.xlabel('Año')
plt.ylabel('Número de Filas')
plt.xticks(rotation=0)
plt.show()

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografias 2013.csv'
# Cargar el CSV, omitiendo la primera fila
# Cargar el archivo CSV
df_13 = pd.read_csv(file_path, encoding='latin1',skiprows=1)  # Ajustar encoding si es necesario

# Eliminar columnas
df_13 = df_13.drop(columns=['Clave Entidad'])
df_13 = df_13.drop(columns=['Clave Jurisdicción'])
df_13 = df_13.drop(columns=['Jurisdicción'])
df_13 = df_13.drop(columns=['Clave Municipio'])
df_13 = df_13.drop(columns=['Municipio'])
df_13 = df_13.drop(columns=['Fecha Toma Masto'])
df_13 = df_13.drop(columns=['Fecha Interpretación Masto'])

# Renombrar las columnas
df_13 = df_13.rename(columns={'Entidad': 'entidad','Edad': 'edad', 'Resultado': 'resultado'})

#añadir año
df_13['año'] = 2013
df_13

# Reordenar las columnas
df_13 = df_13[['entidad', 'resultado', 'edad', 'año']]
df_13
# Out:
#                entidad              resultado  edad   año
# 0       Aguascalientes  Probablemente Benigna    52  2013
# 1       Aguascalientes               Negativa    48  2013
# 2       Aguascalientes               Negativa    48  2013
# 3       Aguascalientes               Negativa    69  2013
# 4       Aguascalientes               Negativa    44  2013
# ...                ...                    ...   ...   ...
# 790059       Zacatecas                Benigna    43  2013
# 790060       Zacatecas               Negativa    55  2013
# 790061       Zacatecas               Negativa    58  2013
# 790062       Zacatecas               Negativa    45  2013
# 790063       Zacatecas                Benigna    69  2013
#
# [790064 rows x 4 columns]

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2014.csv'
# Cargar el archivo CSV
df_14 = pd.read_csv(file_path, encoding='latin1',skiprows=1)  # Ajustar encoding si es necesario


# Eliminar columnas
df_14 = df_14.drop(columns=['Clave Entidad'])
df_14 = df_14.drop(columns=['Clave Jurisdicción'])
df_14 = df_14.drop(columns=['Jurisdicción'])
df_14 = df_14.drop(columns=['Clave Municipio'])
df_14 = df_14.drop(columns=['Municipio'])
df_14 = df_14.drop(columns=['Fecha Toma Masto'])
df_14 = df_14.drop(columns=['Fecha Interpretación Masto'])

# Renombrar las columnas
df_14 = df_14.rename(columns={'Entidad': 'entidad','Edad': 'edad', 'Resultado': 'resultado'})

#añadir año
df_14['año'] = 2014
df_14

# Reordenar las columnas
df_14 = df_14[['entidad', 'resultado', 'edad', 'año']]
df_14
# Out:
#                entidad             resultado  edad   año
# 0       Aguascalientes               Benigna    47  2014
# 1       Aguascalientes               Benigna    46  2014
# 2       Aguascalientes              Negativa    43  2014
# 3       Aguascalientes               Benigna    55  2014
# 4       Aguascalientes               Benigna    40  2014
# ...                ...                   ...   ...   ...
# 816708       Zacatecas              Negativa    66  2014
# 816709       Zacatecas               Benigna    43  2014
# 816710       Zacatecas              Negativa    59  2014
# 816711       Zacatecas               Benigna    54  2014
# 816712       Zacatecas  Evaluación Adicional    42  2014
#
# [816713 rows x 4 columns]

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2015.csv'
# Cargar el archivo CSV
df_15 = pd.read_csv(file_path, encoding='latin1',skiprows=1)  # Ajustar encoding si es necesario

# Eliminar columnas
df_15 = df_15.drop(columns=['Clave Entidad'])
df_15 = df_15.drop(columns=['Clave Jurisdicción'])
df_15 = df_15.drop(columns=['Jurisdicción'])
df_15 = df_15.drop(columns=['Clave Municipio'])
df_15 = df_15.drop(columns=['Municipio'])
df_15 = df_15.drop(columns=['Fecha Toma Masto'])
df_15 = df_15.drop(columns=['Fecha Interpretación Masto'])

# Renombrar las columnas
df_15 = df_15.rename(columns={'Entidad': 'entidad','Edad': 'edad', 'Resultado': 'resultado'})

#añadir año
df_15['año'] = 2015
df_15

# Reordenar las columnas
df_15 = df_15[['entidad', 'resultado', 'edad', 'año']]


df_15
# Out:
# <ipython-input-200-94d7cf0e030f>:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_15 = pd.read_csv(file_path, encoding='latin1',skiprows=1)  # Ajustar encoding si es necesario
#                entidad resultado  edad   año
# 0       Aguascalientes   Benigna    49  2015
# 1       Aguascalientes   Benigna    43  2015
# 2       Aguascalientes   Benigna    65  2015
# 3       Aguascalientes   Benigna    46  2015
# 4       Aguascalientes   Benigna    41  2015
# ...                ...       ...   ...   ...
# 944800       Zacatecas   Benigna    52  2015
# 944801       Zacatecas  Negativa    48  2015
# 944802       Zacatecas  Negativa    48  2015
# 944803       Zacatecas   Benigna    52  2015
# 944804       Zacatecas  Negativa    58  2015
#
# [944805 rows x 4 columns]

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2016.csv'

# Cargar el archivo CSV
df_16 = pd.read_csv(file_path, encoding='latin1', skiprows=1)  # Ajustar encoding si es necesario

# Eliminar columnas
df_16 = df_16.drop(columns=['Clave Entidad'])
df_16 = df_16.drop(columns=['Clave Jurisdicción'])
df_16 = df_16.drop(columns=['Jurisdicción'])
df_16 = df_16.drop(columns=['Clave Municipio'])
df_16 = df_16.drop(columns=['Municipio'])
df_16 = df_16.drop(columns=['Fecha Toma Masto'])
df_16 = df_16.drop(columns=['Fecha Interpretación Masto'])

# Renombrar las columnas
df_16 = df_16.rename(columns={'Entidad': 'entidad', 'Edad': 'edad', 'Resultado': 'resultado'})

# Añadir año
df_16['año'] = 2016
df_16

# Reordenar las columnas
df_16 = df_16[['entidad', 'resultado', 'edad', 'año']]

df_16
# Out:
#                entidad resultado  edad   año
# 0       Aguascalientes   Benigna    49  2016
# 1       Aguascalientes   Benigna    44  2016
# 2       Aguascalientes   Benigna    49  2016
# 3       Aguascalientes   Benigna    48  2016
# 4       Aguascalientes   Benigna    52  2016
# ...                ...       ...   ...   ...
# 855313       Zacatecas  Negativa    47  2016
# 855314       Zacatecas  Negativa    53  2016
# 855315       Zacatecas  Negativa    53  2016
# 855316       Zacatecas  Negativa    53  2016
# 855317       Zacatecas   Benigna    41  2016
#
# [855318 rows x 4 columns]

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2017.csv'

# Cargar el archivo CSV
df_17 = pd.read_csv(file_path, encoding='latin1', skiprows=1)  # Ajustar encoding si es necesario

# Eliminar columnas
df_17 = df_17.drop(columns=['Clave Entidad'])
df_17 = df_17.drop(columns=['Clave Jurisdicción'])
df_17 = df_17.drop(columns=['Jurisdicción'])
df_17 = df_17.drop(columns=['Clave Municipio'])
df_17 = df_17.drop(columns=['Municipio'])
df_17 = df_17.drop(columns=['Fecha Toma Masto'])
df_17 = df_17.drop(columns=['Fecha Interpretación Masto'])

# Renombrar las columnas
df_17 = df_17.rename(columns={'Entidad': 'entidad', 'Edad': 'edad', 'Resultado': 'resultado'})

# Añadir año
df_17['año'] = 2017
df_17

# Reordenar las columnas
df_17 = df_17[['entidad', 'resultado', 'edad', 'año']]

df_17
# Out:
#                entidad                         resultado  edad   año
# 0       Aguascalientes  Altamente Sugestiva a Malignidad    57  2017
# 1       Aguascalientes  Altamente Sugestiva a Malignidad    57  2017
# 2       Aguascalientes             Probablemente Benigna    57  2017
# 3       Aguascalientes              Evaluación Adicional    57  2017
# 4       Aguascalientes  Altamente Sugestiva a Malignidad    57  2017
# ...                ...                               ...   ...   ...
# 855012       Zacatecas                           Benigna    47  2017
# 855013       Zacatecas              Evaluación Adicional    49  2017
# 855014       Zacatecas                           Benigna    57  2017
# 855015       Zacatecas              Evaluación Adicional    67  2017
# 855016       Zacatecas                           Benigna    44  2017
#
# [855017 rows x 4 columns]

# %%
# Añadir las filas de df2 a df1
df_combined = pd.concat([df_13,df_14,df_15,df_16,df_17, df_18,df_19,df_20,df_21,df_22,df_23], ignore_index=True)

# Convertir la columna 'edad' a tipo int
df_combined['edad'] = df_combined['edad'].astype(int)


df_combined
# Out:
#                 entidad              resultado  edad   año
# 0        Aguascalientes  Probablemente Benigna    52  2013
# 1        Aguascalientes               Negativa    48  2013
# 2        Aguascalientes               Negativa    48  2013
# 3        Aguascalientes               Negativa    69  2013
# 4        Aguascalientes               Negativa    44  2013
# ...                 ...                    ...   ...   ...
# 7723743       Zacatecas                Benigna    51  2023
# 7723744       Zacatecas                Benigna    51  2023
# 7723745       Zacatecas                Benigna    51  2023
# 7723746       Zacatecas               Negativa    50  2023
# 7723747       Zacatecas                Benigna    51  2023
#
# [7723748 rows x 4 columns]

# %%
# Especifica la ruta donde quieres guardar el archivo en tu Google Drive
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2013 - 2023.csv'

# Guarda el DataFrame como un archivo CSV
df_combined.to_csv(file_path, index=False)

# %%
# Contar cuántas veces aparece cada año
count_by_year = df_combined['año'].value_counts().sort_index()

# Graficar
plt.figure(figsize=(8, 6))
count_by_year.plot(kind='bar', color='skyblue')
plt.title('Número de Mastografías de 2013 a 2023 en México')
plt.xlabel('Año')
plt.ylabel('Número de Mastografías')
plt.xticks(rotation=0)
plt.show()

# %%
count_by_year
# Out:
# año
# 2013    790064
# 2014    816713
# 2015    944805
# 2016    855318
# 2017    855017
# 2018    816904
# 2019    790718
# 2020    324586
# 2021    420947
# 2022    577921
# 2023    530755
# Name: count, dtype: int64

# %%
# Especifica la ruta donde quieres guardar el archivo en tu Google Drive
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023/Mastografías 2013 - 2023.csv'
df = pd.read_csv(file_path)
len(df)
# Out:
# 7723748

# %%
df
# Out:
#                 entidad              resultado  edad   año
# 0        Aguascalientes  Probablemente Benigna    52  2013
# 1        Aguascalientes               Negativa    48  2013
# 2        Aguascalientes               Negativa    48  2013
# 3        Aguascalientes               Negativa    69  2013
# 4        Aguascalientes               Negativa    44  2013
# ...                 ...                    ...   ...   ...
# 7723743       Zacatecas                Benigna    51  2023
# 7723744       Zacatecas                Benigna    51  2023
# 7723745       Zacatecas                Benigna    51  2023
# 7723746       Zacatecas               Negativa    50  2023
# 7723747       Zacatecas                Benigna    51  2023
#
# [7723748 rows x 4 columns]

# %%
# Mostrar todas las filas que contienen valores NaN en el dataframe
df_nan = df[df.isna().any(axis=1)]
print(df_nan)
print(len(df_nan))
# Out:
#                  entidad resultado  edad   año
# 31934    Baja California       NaN    53  2013
# 216975        Guanajuato       NaN    60  2013
# 242701        Guanajuato       NaN    43  2013
# 526331        Nuevo León       NaN    33  2013
# 526332        Nuevo León       NaN    33  2013
# 526333        Nuevo León       NaN    33  2013
# 526334        Nuevo León       NaN    56  2013
# 527452        Nuevo León       NaN    39  2013
# 593703            Puebla       NaN    47  2013
# 691911           Sinaloa       NaN    45  2013
# 705939            Sonora       NaN    39  2013
# 735915        Tamaulipas       NaN    43  2013
# 771822           Yucatán       NaN    46  2013
# 852435           Chiapas       NaN    44  2014
# 874408         Chihuahua       NaN    43  2014
# 995340        Guanajuato       NaN    41  2014
# 1400932           Puebla       NaN    43  2014
# 1450450        Querétaro       NaN    30  2014
# 1512231           Sonora       NaN    40  2014
# ...

# %%
# Calcular la moda de la columna 'resultado' en el dataframe df
moda_resultado = df['resultado'].mode()
moda_resultado
# Out:
# 0    Benigna
# Name: resultado, dtype: object

# %%
# Calcular la cantidad de filas para cada valor único en la columna 'resultado'
resultado_counts = df['resultado'].value_counts()
resultado_counts
# Out:
# resultado
# Benigna                             5669328
# Negativa                            1203772
# Evaluación Adicional                 545922
# Probablemente Benigna                238139
# Anormalidad Sospechosa                34520
# Altamente Sugestiva a Malignidad      14999
# Riesgo Intermedio de Malignidad        7171
# Baja Sospecha de Malignidad            6692
# Riesgo Moderado de Malignidad          3178
# Name: count, dtype: int64

# %%
# Definir los valores de los resultados de las mastografías
resultados = {
    'Benigna': 5669328,
    'Negativa': 1203772,
    'Evaluación Adicional': 545922,
    'Probablemente Benigna': 238139,
    'Anormalidad Sospechosa': 34520,
    'Altamente Sugestiva a Malignidad': 14999,
    'Riesgo Intermedio de Malignidad': 7171,
    'Baja Sospecha de Malignidad': 6692,
    'Riesgo Moderado de Malignidad': 3178
}

# Calcular el total de mastografías
total_mastografias = sum(resultados.values())

# Calcular los porcentajes de cada resultado
porcentajes = {key: (value / total_mastografias) * 100 for key, value in resultados.items()}

porcentajes
# Out:
# {'Benigna': 73.40151204322373,
#  'Negativa': 15.585389477429338,
#  'Evaluación Adicional': 7.06812169937262,
#  'Probablemente Benigna': 3.0832159784124777,
#  'Anormalidad Sospechosa': 0.4469348387907849,
#  'Altamente Sugestiva a Malignidad': 0.19419396428224167,
#  'Riesgo Intermedio de Malignidad': 0.09284385078124908,
#  'Baja Sospecha de Malignidad': 0.086642176743567,
#  'Riesgo Moderado de Malignidad': 0.0411459709639952}

# %%
# Reemplazar los valores NaN en la columna 'resultado' por la moda de 'resultado'
moda_resultado = df['resultado'].mode()[0]
df['resultado'] = df['resultado'].fillna(moda_resultado)

df['resultado'].isna().sum()  # Verificar si hay algún valor NaN restante en 'resultado'
# Out:
# 0

# %%
df
# Out:
#                 entidad              resultado  edad   año
# 0        Aguascalientes  Probablemente Benigna    52  2013
# 1        Aguascalientes               Negativa    48  2013
# 2        Aguascalientes               Negativa    48  2013
# 3        Aguascalientes               Negativa    69  2013
# 4        Aguascalientes               Negativa    44  2013
# ...                 ...                    ...   ...   ...
# 7723743       Zacatecas                Benigna    51  2023
# 7723744       Zacatecas                Benigna    51  2023
# 7723745       Zacatecas                Benigna    51  2023
# 7723746       Zacatecas               Negativa    50  2023
# 7723747       Zacatecas                Benigna    51  2023
#
# [7723748 rows x 4 columns]

# %%
# Especifica la ruta donde quieres guardar el archivo en tu Google Drive
file_path = '/content/drive/MyDrive/Cancer de mama/Mastografias 2013 - 2023 en mexico/Mastografías 2013 - 2023.csv'

# Guarda el DataFrame como un archivo CSV
df.to_csv(file_path, index=False)

# %%
df
# Out:
#                 entidad              resultado  edad   año
# 0        Aguascalientes  Probablemente Benigna    52  2013
# 1        Aguascalientes               Negativa    48  2013
# 2        Aguascalientes               Negativa    48  2013
# 3        Aguascalientes               Negativa    69  2013
# 4        Aguascalientes               Negativa    44  2013
# ...                 ...                    ...   ...   ...
# 7723743       Zacatecas                Benigna    51  2023
# 7723744       Zacatecas                Benigna    51  2023
# 7723745       Zacatecas                Benigna    51  2023
# 7723746       Zacatecas               Negativa    50  2023
# 7723747       Zacatecas                Benigna    51  2023
#
# [7723748 rows x 4 columns]

# %%
# Contar cuántas veces aparece cada año
count_by_year = df['año'].value_counts().sort_index()

# Graficar
plt.figure(figsize=(8, 6))
count_by_year.plot(kind='bar', color='skyblue')
plt.title('Número de Mastografías de 2013 a 2023 en México')
plt.xlabel('Año')
plt.ylabel('Número de Mastografías')
plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Definir el orden de gravedad para los resultados
orden_gravedad = [
    'Evaluación Adicional',
    'Negativa',
    'Benigna',
    'Probablemente Benigna',
    'Anormalidad Sospechosa',
    'Riesgo Moderado de Malignidad',
    'Baja Sospecha de Malignidad',
    'Riesgo Intermedio de Malignidad',
    'Altamente Sugestiva a Malignidad'
]

# Contar las ocurrencias de cada valor en la columna 'resultado'
resultado_counts = df['resultado'].value_counts()

# Reordenar los resultados según el orden de gravedad
resultado_counts = resultado_counts[orden_gravedad]

# Crear la gráfica
plt.figure(figsize=(10,6))
sns.barplot(x=resultado_counts.index, y=resultado_counts.values, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Resultado', fontsize=12)
plt.ylabel('Número de Mastografías', fontsize=12)
plt.title('Número de Mastografías por resultado (Ordenado por Gravedad)', fontsize=14)
plt.show()
# Out:
# <ipython-input-241-a770d4e6f4df>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=resultado_counts.index, y=resultado_counts.values, palette='viridis')

# %%
resultado_counts = df['resultado'].value_counts()
resultado_counts
# Out:
# resultado
# Benigna                             5669355
# Negativa                            1203772
# Evaluación Adicional                 545922
# Probablemente Benigna                238139
# Anormalidad Sospechosa                34520
# Altamente Sugestiva a Malignidad      14999
# Riesgo Intermedio de Malignidad        7171
# Baja Sospecha de Malignidad            6692
# Riesgo Moderado de Malignidad          3178
# Name: count, dtype: int64

# %% [markdown]
# #tasa de mortalidad en mexico

# %%
import pandas as pd

# %%
file_path = '/content/drive/MyDrive/Cancer de mama/Tasa de mortalidad de 1990 - 2013 en mexico/Tasa_Mortalidad_Cancer_Mama_Serie_Historica.csv'
df = pd.read_csv(file_path)
df
# Out:
#      Periodo Entidad de Residencia  Defunciones por Cancer de Mama  \
# 0       1990        Aguascalientes                              29
# 1       1990       Baja California                              79
# 2       1990   Baja California Sur                               7
# 3       1990              Campeche                              12
# 4       1990  Coahuila de Zaragoza                              62
# ..       ...                   ...                             ...
# 787     2013              Tlaxcala                              45
# 788     2013        Veracruz Llave                             353
# 789     2013               Yucatán                              80
# 790     2013             Zacatecas                              82
# 791     2013              Nacional                            5405
#
#      Poblacion Femenina Total  Tasa de Mortalidad por Cancer de Mama
# 0                      159967                              18.128739
# ...

# %%
import pandas as pd

# Suponiendo que ya tienes un DataFrame llamado df
# Agrupar por "Periodo" y sumar las columnas relevantes
df_grouped = df.groupby('Periodo').agg({
    'Defunciones por Cancer de Mama': 'sum',
    'Poblacion Femenina Total': 'sum'
}).reset_index()

# Calcular la tasa de mortalidad
df_grouped['Tasa de Mortalidad por Cancer de Mama'] = (df_grouped['Defunciones por Cancer de Mama'] / df_grouped['Poblacion Femenina Total']) * 100000

# Ahora df_grouped tiene los resultados agregados por año y la tasa recalculada
df_grouped
# Out:
#     Periodo  Defunciones por Cancer de Mama  Poblacion Femenina Total  \
# 0      1990                            4380                  35852664
# 1      1991                            4668                  37007840
# 2      1992                            5036                  38193064
# 3      1993                            5352                  39392350
# 4      1994                            5478                  40623620
# 5      1995                            5960                  41890024
# 6      1996                            6130                  43182190
# 7      1997                            6362                  44490494
# 8      1998                            6692                  45816222
# 9      1999                            6764                  47132266
# 10     2000                            6838                  48432714
# 11     2001                            7126                  49756872
# ...

# %%
file_path_2 = '/content/drive/MyDrive/Cancer de mama/Tasa de mortalidad de 1990 - 2013 en mexico/Tasa_de_mortalidad_por_cxncer_de_mama.csv'
df2 = pd.read_csv(file_path_2)
df2
# Out:
#       AÑO  CLAVE ENTIDAD    ENTIDAD  CLAVE SEXO     SEXO  \
# 0    2010              0   Nacional           2  Mujeres
# 1    2011              0   Nacional           2  Mujeres
# 2    2012              0   Nacional           2  Mujeres
# 3    2013              0   Nacional           2  Mujeres
# 4    2014              0   Nacional           2  Mujeres
# ..    ...            ...        ...         ...      ...
# 226  2012             32  Zacatecas           2  Mujeres
# 227  2013             32  Zacatecas           2  Mujeres
# 228  2014             32  Zacatecas           2  Mujeres
# 229  2015             32  Zacatecas           2  Mujeres
# 230  2016             32  Zacatecas           2  Mujeres
#
#      DEFUNCIONES POR CÁNCER DE MAMA EN MUJERES DE 25 AÑOS O MÁS   \
# 0                                                 5037
# 1                                                 5207
# 2                                                 5584
# ...

# %%
# Ver cuántas respuestas hay para la columna 'SEXO' y el conteo de cada una
sexo_counts = df2['SEXO'].value_counts()

# Mostrar el resultado
print(sexo_counts)
# Out:
# SEXO
# Mujeres    231
# Name: count, dtype: int64

# %%
# Obtener los nombres de todas las columnas
columnas = df2.columns

# Mostrar los nombres de las columnas
print(columnas)
# Out:
# Index(['AÑO', 'CLAVE ENTIDAD', 'ENTIDAD', 'CLAVE SEXO', 'SEXO',
#        'DEFUNCIONES POR CÁNCER DE MAMA EN MUJERES DE 25 AÑOS O MÁS ',
#        'POBLACIÓN DE MUJERES DE 25 AÑOS O MÁS',
#        'TASA DE MORTALIDAD POR CÁNCER DE MAMA'],
#       dtype='object')

# %%
# Agrupar por "AÑO" y sumar las columnas relevantes
df_grouped2 = df2.groupby('AÑO').agg({
    'DEFUNCIONES POR CÁNCER DE MAMA EN MUJERES DE 25 AÑOS O MÁS ': 'sum',
    'POBLACIÓN DE MUJERES DE 25 AÑOS O MÁS': 'sum'
}).reset_index()

# Calcular la tasa de mortalidad
df_grouped2['Tasa de Mortalidad por Cancer de Mama'] = (df_grouped2['DEFUNCIONES POR CÁNCER DE MAMA EN MUJERES DE 25 AÑOS O MÁS '] / df_grouped2['POBLACIÓN DE MUJERES DE 25 AÑOS O MÁS']) * 100000

# Ahora df_grouped2 tiene los resultados agregados por año y la tasa recalculada
df_grouped2
# Out:
#     AÑO  DEFUNCIONES POR CÁNCER DE MAMA EN MUJERES DE 25 AÑOS O MÁS   \
# 0  2010                                              10074
# 1  2011                                              10414
# 2  2012                                              11168
# 3  2013                                              11052
# 4  2014                                              11948
# 5  2015                                              12552
# 6  2016                                              13260
#
#    POBLACIÓN DE MUJERES DE 25 AÑOS O MÁS  \
# 0                               62304782
# 1                               63710053
# 2                               65116779
# 3                               66521317
# 4                               67935405
# 5                               69358429
# 6                               70783734
#
#    Tasa de Mortalidad por Cancer de Mama
# 0                              16.168903
# 1                              16.345929
# ...

# %%
# Nuevos nombres de las columnas
nuevos_nombres = ['Año', 'Defunciones por cáncer de mama en mujeres de 25 años o más',
                  'Población de mujeres de 25 años o más', 'Tasa de mortalidad por cáncer de mama']

# Asignar los nuevos nombres de columna al DataFrame
df_grouped2.columns = nuevos_nombres

# Verificar los cambios
print(df_grouped2.columns)
# Out:
# Index(['Año', 'Defunciones por cáncer de mama en mujeres de 25 años o más',
#        'Población de mujeres de 25 años o más',
#        'Tasa de mortalidad por cáncer de mama'],
#       dtype='object')

# %%
# Asignar los nuevos nombres de columna al DataFrame
df_grouped.columns = nuevos_nombres

# Verificar los cambios
print(df_grouped.columns)
# Out:
# Index(['Año', 'Defunciones por cáncer de mama en mujeres de 25 años o más',
#        'Población de mujeres de 25 años o más',
#        'Tasa de mortalidad por cáncer de mama'],
#       dtype='object')

# %%
df_grouped
# Out:
#      Año  Defunciones por cáncer de mama en mujeres de 25 años o más  \
# 0   1990                                               4380
# 1   1991                                               4668
# 2   1992                                               5036
# 3   1993                                               5352
# 4   1994                                               5478
# 5   1995                                               5960
# 6   1996                                               6130
# 7   1997                                               6362
# 8   1998                                               6692
# 9   1999                                               6764
# 10  2000                                               6838
# 11  2001                                               7126
# 12  2002                                               7644
# 13  2003                                               7722
# ...

# %%
# Filtrar el DataFrame para mantener solo las filas donde 'Año' sea menor que 2010
df_filtrado = df_grouped.loc[df_grouped['Año'] < 2010]

# Ahora df_filtrado tiene solo las filas con 'Año' menor a 2010
df_filtrado
# Out:
#      Año  Defunciones por cáncer de mama en mujeres de 25 años o más  \
# 0   1990                                               4380
# 1   1991                                               4668
# 2   1992                                               5036
# 3   1993                                               5352
# 4   1994                                               5478
# 5   1995                                               5960
# 6   1996                                               6130
# 7   1997                                               6362
# 8   1998                                               6692
# 9   1999                                               6764
# 10  2000                                               6838
# 11  2001                                               7126
# 12  2002                                               7644
# 13  2003                                               7722
# ...

# %%
# Concatenar las filas de df_grouped2 a df_filtrado
df_combinado = pd.concat([df_filtrado, df_grouped2], ignore_index=True)

# Ver el DataFrame resultante
df_combinado
# Out:
#      Año  Defunciones por cáncer de mama en mujeres de 25 años o más  \
# 0   1990                                               4380
# 1   1991                                               4668
# 2   1992                                               5036
# 3   1993                                               5352
# 4   1994                                               5478
# 5   1995                                               5960
# 6   1996                                               6130
# 7   1997                                               6362
# 8   1998                                               6692
# 9   1999                                               6764
# 10  2000                                               6838
# 11  2001                                               7126
# 12  2002                                               7644
# 13  2003                                               7722
# ...

# %%
#montar drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Especifica la ruta donde deseas guardar el archivo (ajusta la carpeta y nombre)
ruta_guardado = '/content/drive/MyDrive/Cancer de mama/Tasa de mortalidad de 1990 - 2013 en mexico/mortalidad 90-16.csv'

# Guardar el DataFrame como archivo CSV
df_combinado.to_csv(ruta_guardado, index=False)

print("Archivo guardado en: ", ruta_guardado)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c0cbc0f8ee34> in <cell line: 5>()
#       3
#       4 # Guardar el DataFrame como archivo CSV
# ----> 5 df_combinado.to_csv(ruta_guardado, index=False)
#       6
#       7 print("Archivo guardado en: ", ruta_guardado)
#
# NameError: name 'df_combinado' is not defined

# %%
import pandas as pd
ruta_guardado = '/content/drive/MyDrive/Cancer de mama/Tasa de mortalidad de 1990 - 2013 en mexico/mortalidad 90-16.csv'
df = pd.read_csv(ruta_guardado)
df
# Out:
#      Año  Defunciones por cáncer de mama en mujeres de 25 años o más  \
# 0   1990                                               4380
# 1   1991                                               4668
# 2   1992                                               5036
# 3   1993                                               5352
# 4   1994                                               5478
# 5   1995                                               5960
# 6   1996                                               6130
# 7   1997                                               6362
# 8   1998                                               6692
# 9   1999                                               6764
# 10  2000                                               6838
# 11  2001                                               7126
# 12  2002                                               7644
# 13  2003                                               7722
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Graficar Año vs Defunciones por Cáncer de Mama en Mujeres de 25 Años o Más
plt.figure(figsize=(10,6))
plt.plot(df['Año'], df['Defunciones por cáncer de mama en mujeres de 25 años o más'], color='red', marker='o', linestyle='-', label='Defunciones')
plt.title('Año vs Defunciones por Cáncer de Mama en Mujeres de 25 Años o Más')
plt.xlabel('Año')
plt.ylabel('Defunciones')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Graficar Año vs Población de Mujeres de 25 Años o Más
plt.figure(figsize=(10,6))
plt.plot(df['Año'], df['Población de mujeres de 25 años o más'], color='blue', marker='o', linestyle='-', label='Población')
plt.title('Año vs Población de Mujeres de 25 Años o Más')
plt.xlabel('Año')
plt.ylabel('Población')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Graficar Año vs Tasa de Mortalidad por Cáncer de Mama
plt.figure(figsize=(10,6))
plt.plot(df['Año'], df['Tasa de mortalidad por cáncer de mama'], color='green', marker='o', linestyle='-', label='Tasa de Mortalidad')
plt.title('Año vs Tasa de Mortalidad por Cáncer de Mama')
plt.xlabel('Año')
plt.ylabel('Tasa de Mortalidad')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtrar el DataFrame para los años 2013 a 2016
df_filtered = df[(df['Año'] >= 2013) & (df['Año'] <= 2016)]

# Graficar Año vs Defunciones por Cáncer de Mama en Mujeres de 25 Años o Más
plt.figure(figsize=(10,6))
plt.plot(df_filtered['Año'], df_filtered['Defunciones por cáncer de mama en mujeres de 25 años o más'], color='red', marker='o', linestyle='-', label='Defunciones')
plt.title('Año vs Defunciones por Cáncer de Mama en Mujeres de 25 Años o Más (2013-2016)')
plt.xlabel('Año')
plt.ylabel('Defunciones')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Graficar Año vs Población de Mujeres de 25 Años o Más
plt.figure(figsize=(10,6))
plt.plot(df_filtered['Año'], df_filtered['Población de mujeres de 25 años o más'], color='blue', marker='o', linestyle='-', label='Población')
plt.title('Año vs Población de Mujeres de 25 Años o Más (2013-2016)')
plt.xlabel('Año')
plt.ylabel('Población')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Graficar Año vs Tasa de Mortalidad por Cáncer de Mama
plt.figure(figsize=(10,6))
plt.plot(df_filtered['Año'], df_filtered['Tasa de mortalidad por cáncer de mama'], color='green', marker='o', linestyle='-', label='Tasa de Mortalidad')
plt.title('Año vs Tasa de Mortalidad por Cáncer de Mama (2013-2016)')
plt.xlabel('Año')
plt.ylabel('Tasa de Mortalidad')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Crear el DataFrame con los datos proporcionados
data = {
    "Año": [2010, 2011, 2012, 2013, 2014, 2015, 2016],
    "Defunciones por cáncer de mama en mujeres de 25 años o más": [5024, 5206, 5583, 5526, 5974, 6252, 6629],
    "Población de mujeres de 25 años o más": [
        30844960, 31604691, 32362693, 33119331, 33873575, 34611681, 35344978
    ],
    "Tasa de mortalidad por cáncer de mama": [
        16.3203324, 16.47223825, 17.25134555, 16.68511964, 17.63616624, 18.06326598, 18.7551397
    ],
}

df2 = pd.DataFrame(data)
df2
# Out:
#     Año  Defunciones por cáncer de mama en mujeres de 25 años o más  \
# 0  2010                                               5024
# 1  2011                                               5206
# 2  2012                                               5583
# 3  2013                                               5526
# 4  2014                                               5974
# 5  2015                                               6252
# 6  2016                                               6629
#
#    Población de mujeres de 25 años o más  \
# 0                               30844960
# 1                               31604691
# 2                               32362693
# 3                               33119331
# 4                               33873575
# 5                               34611681
# 6                               35344978
#
#    Tasa de mortalidad por cáncer de mama
# 0                              16.320332
# 1                              16.472238
# ...

# %%
import matplotlib.pyplot as plt

# Filtrar el DataFrame df para que solo contenga datos entre 2010 y 2016
df_filtered = df[(df["Año"] >= 2010) & (df["Año"] <= 2016)]

# Crear las gráficas comparativas
columns_to_compare = [
    "Defunciones por cáncer de mama en mujeres de 25 años o más",
    "Población de mujeres de 25 años o más",
    "Tasa de mortalidad por cáncer de mama",
]

plt.figure(figsize=(15, 12))
for i, column in enumerate(columns_to_compare, 1):
    plt.subplot(3, 1, i)
    plt.plot(df_filtered["Año"], df_filtered[column], label="Secretaría de Salud", marker="o")
    plt.plot(df2["Año"], df2[column], label="SNEDH", marker="x")
    plt.title(f"Año vs {column}")
    plt.xlabel("Año")
    plt.ylabel(column)
    plt.legend()
    plt.grid()

plt.tight_layout()
plt.show()

# %%
# Comparar tasa de mortalidad
df_comparison = df_filtered.merge(df2, on="Año", suffixes=("_salud", "_snedh"))

# Calcular la precisión para la tasa de mortalidad
df_comparison["Diferencia Tasa de Mortalidad (%)"] = abs(
    df_comparison["Tasa de mortalidad por cáncer de mama_salud"]
    - df_comparison["Tasa de mortalidad por cáncer de mama_snedh"]
) / df_comparison["Tasa de mortalidad por cáncer de mama_salud"] * 100

precision_tasa = 100 - df_comparison["Diferencia Tasa de Mortalidad (%)"].mean()

# Calcular las diferencias relativas para población y defunciones
df_comparison["Diferencia Población (%)"] = abs(
    df_comparison["Población de mujeres de 25 años o más_salud"]
    - df_comparison["Población de mujeres de 25 años o más_snedh"]
) / df_comparison["Población de mujeres de 25 años o más_salud"] * 100

df_comparison["Diferencia Defunciones (%)"] = abs(
    df_comparison["Defunciones por cáncer de mama en mujeres de 25 años o más_salud"]
    - df_comparison["Defunciones por cáncer de mama en mujeres de 25 años o más_snedh"]
) / df_comparison["Defunciones por cáncer de mama en mujeres de 25 años o más_salud"] * 100

# Promedio de diferencias relativas
diferencia_poblacion = df_comparison["Diferencia Población (%)"].mean()
diferencia_defunciones = df_comparison["Diferencia Defunciones (%)"].mean()

# Resultados
precision_tasa, diferencia_poblacion, diferencia_defunciones
# Out:
# (99.52769300201372, 50.24307315854816, 50.04947824950068)

# %%
import pandas as pd

# Data for the population of women over 25 years from 1990 to 2020
data = {
    "Año": [1990, 1995, 2000, 2005, 2010, 2020],
    "Población de mujeres mayores de 25 años": [16690364, 20275132, 22948793, 26195454, 30181997, 38132240]
}

# Create the DataFrame
df_poblacion_mujeres = pd.DataFrame(data)

# Display the DataFrame
print(df_poblacion_mujeres)
# Out:
#     Año  Población de mujeres mayores de 25 años
# 0  1990                                 16690364
# 1  1995                                 20275132
# 2  2000                                 22948793
# 3  2005                                 26195454
# 4  2010                                 30181997
# 5  2020                                 38132240

# %%
# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(df_poblacion_mujeres["Año"], df_poblacion_mujeres["Población de mujeres mayores de 25 años"], marker="o", color="b")
plt.title("Población de mujeres mayores de 25 años en México (1990-2020)")
plt.xlabel("Año")
plt.ylabel("Población de mujeres mayores de 25 años")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Datos existentes de la población de mujeres mayores de 25 años
data = {
    "Año": [1990, 1995, 2000, 2005, 2010, 2020],
    "Población de mujeres mayores de 25 años": [16690364, 20275132, 22948793, 26195454, 30181997, 38132240]
}

df_poblacion_mujeres = pd.DataFrame(data)

# Crear un rango de años de 1990 a 2023
years = np.arange(1990, 2024).reshape(-1, 1)

# Extraer los valores de los años disponibles y las poblaciones disponibles
available_years = df_poblacion_mujeres["Año"].values.reshape(-1, 1)
available_population = df_poblacion_mujeres["Población de mujeres mayores de 25 años"].values

# Crear y entrenar el modelo de regresión lineal
model = LinearRegression()
model.fit(available_years, available_population)

# Predecir la población para los años de 1990 a 2023
predicted_population = model.predict(years)

# Crear un DataFrame con los años y las poblaciones predichas
df_predicted = pd.DataFrame({
    "Año": years.flatten(),
    "Población de mujeres mayores de 25 años (predicha)": predicted_population
})

# Mostrar el DataFrame con las predicciones
print(df_predicted)

# Graficar los resultados
plt.figure(figsize=(10, 6))
plt.plot(df_poblacion_mujeres["Año"], df_poblacion_mujeres["Población de mujeres mayores de 25 años"], marker="o", label="Datos reales", color="b")
plt.plot(df_predicted["Año"], df_predicted["Población de mujeres mayores de 25 años (predicha)"], marker="x", label="Predicciones", color="r")
plt.title("Población de mujeres mayores de 25 años (1990-2023) - Predicción")
plt.xlabel("Año")
plt.ylabel("Población de mujeres mayores de 25 años")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#      Año  Población de mujeres mayores de 25 años (predicha)
# 0   1990                                       1.631068e+07
# 1   1991                                       1.701767e+07
# 2   1992                                       1.772467e+07
# 3   1993                                       1.843167e+07
# 4   1994                                       1.913867e+07
# 5   1995                                       1.984567e+07
# 6   1996                                       2.055267e+07
# 7   1997                                       2.125967e+07
# 8   1998                                       2.196667e+07
# 9   1999                                       2.267367e+07
# 10  2000                                       2.338067e+07
# 11  2001                                       2.408767e+07
# 12  2002                                       2.479466e+07
# 13  2003                                       2.550166e+07
# 14  2004                                       2.620866e+07
# ...

# %%
import xgboost as xgb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Datos existentes de la población de mujeres mayores de 25 años
data = {
    "Año": [1990, 1995, 2000, 2005, 2010, 2020],
    "Población de mujeres mayores de 25 años": [16690364, 20275132, 22948793, 26195454, 30181997, 38132240]
}

df_poblacion_mujeres = pd.DataFrame(data)

# Crear un rango de años de 1990 a 2023
years = np.arange(1990, 2024).reshape(-1, 1)

# Extraer los valores de los años disponibles y las poblaciones disponibles
available_years = df_poblacion_mujeres["Año"].values.reshape(-1, 1)
available_population = df_poblacion_mujeres["Población de mujeres mayores de 25 años"].values

# Convertir los datos a formato DMatrix (requerido por XGBoost)
dtrain = xgb.DMatrix(available_years, label=available_population)

# Establecer parámetros para el modelo de XGBoost
params = {
    "objective": "reg:squarederror",  # Regresión
    "colsample_bytree": 0.3,
    "learning_rate": 0.1,
    "max_depth": 5,
    "alpha": 10,
    "n_estimators": 100
}

# Entrenar el modelo
xgb_model = xgb.train(params, dtrain, num_boost_round=100)

# Predecir la población para los años de 1990 a 2023
dtest = xgb.DMatrix(years)
predicted_population_xgb = xgb_model.predict(dtest)

# Crear un DataFrame con los años y las poblaciones predichas
df_predicted_xgb = pd.DataFrame({
    "Año": years.flatten(),
    "Población de mujeres mayores de 25 años (predicha)": predicted_population_xgb
})

# Mostrar el DataFrame con las predicciones
print(df_predicted_xgb)

# Graficar los resultados
plt.figure(figsize=(10, 6))
plt.plot(df_poblacion_mujeres["Año"], df_poblacion_mujeres["Población de mujeres mayores de 25 años"], marker="o", label="Datos reales", color="b")
plt.plot(df_predicted_xgb["Año"], df_predicted_xgb["Población de mujeres mayores de 25 años (predicha)"], marker="x", label="Predicciones - XGBoost", color="g")
plt.title("Población de mujeres mayores de 25 años (1990-2023) - Predicción usando XGBoost")
plt.xlabel("Año")
plt.ylabel("Población de mujeres mayores de 25 años")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [04:47:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
#      Año  Población de mujeres mayores de 25 años (predicha)
# 0   1990                                         16745287.0
# 1   1991                                         16745287.0
# 2   1992                                         16745287.0
# 3   1993                                         16745287.0
# 4   1994                                         16745287.0
# 5   1995                                         20288974.0
# 6   1996                                         20288974.0
# 7   1997                                         20288974.0
# 8   1998                                         20288974.0
# 9   1999                                         20288974.0
# 10  2000                                         22954018.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Datos de población
data = {
    "Año": [1895, 1900, 1910, 1920, 1940, 1950, 1960, 1970, 1980, 1990, 1995, 2000, 2005, 2010, 2020],
    "Población de mujeres mayores de 25 años": [
        2456175, 3314941, 3673909, 3754899, 4161317, 5162134, 6544979, 8564920, 12354763,
        16690364, 20275132, 22948793, 26195454, 30181997, 38132240
    ]
}

# Crear DataFrame
df_poblacion_mujeres = pd.DataFrame(data)

# %%
# Crear el gráfico de dispersión
plt.figure(figsize=(10, 6))
plt.scatter(df_poblacion_mujeres['Año'], df_poblacion_mujeres['Población de mujeres mayores de 25 años'], color='red', label='Datos reales')

# Añadir formato de etiquetas sin notación científica
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: '{:,.0f}'.format(x)))

# Añadir etiquetas y título
plt.xlabel('Año')
plt.ylabel('Población de mujeres mayores de 25 años')
plt.title('Población de mujeres mayores de 25 años por Año')

# Mostrar la leyenda
plt.legend()

# Añadir una cuadrícula
plt.grid(True)

# Mostrar la gráfica
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Configurar pandas y numpy para evitar notación científica
pd.set_option('display.float_format', '{:.0f}'.format)
np.set_printoptions(suppress=True)

# Datos de población
data = {
    "Año": [1895, 1900, 1910, 1920, 1940, 1950, 1960, 1970, 1980, 1990, 1995, 2000, 2005, 2010, 2020],
    "Población de mujeres mayores de 25 años": [
        2456175, 3314941, 3673909, 3754899, 4161317, 5162134, 6544979, 8564920, 12354763,
        16690364, 20275132, 22948793, 26195454, 30181997, 38132240
    ]
}

# Crear DataFrame
df = pd.DataFrame(data)

# Preparar los datos
X = df[["Año"]]
y = df["Población de mujeres mayores de 25 años"]

# Crear características polinómicas (grado 3, por ejemplo)
poly = PolynomialFeatures(degree=3, include_bias=False)
X_poly = poly.fit_transform(X)

# Ajustar el modelo de regresión
model = LinearRegression()
model.fit(X_poly, y)

# Predicción para todo el rango de años
years = np.arange(1895, 2023 + 1).reshape(-1, 1)
years_poly = poly.transform(years)
predictions = model.predict(years_poly)

# Graficar los resultados
plt.figure(figsize=(12, 6))
plt.scatter(X, y, color="red", label="Datos reales")
plt.plot(years, predictions, color="blue", label="Predicción (Regresión Polinómica)")
plt.xlabel("Año")
plt.ylabel("Población de mujeres mayores de 25 años")
plt.title("Predicción de población con Regresión Polinómica")
plt.legend()
plt.grid()

# Formatear el eje y para evitar notación científica
formatter = FuncFormatter(lambda x, _: f'{x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)

plt.show()

# Resultados predichos
df_predictions = pd.DataFrame({"Año": years.flatten(), "Población estimada": predictions})
print(df_predictions)  # Mostrar primeras filas
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
#       Año  Población estimada
# 0    1895             2948882
# 1    1896             2988943
# 2    1897             3026038
# 3    1898             3060337
# 4    1899             3092009
# ..    ...                 ...
# 124  2019            37732257
# 125  2020            38693873
# 126  2021            39673487
# 127  2022            40671268
# 128  2023            41687386
#
# [129 rows x 2 columns]

# %%
df_predictions
# Out:
#       Año  Población estimada
# 0    1895             2948882
# 1    1896             2988943
# 2    1897             3026038
# 3    1898             3060337
# 4    1899             3092009
# ..    ...                 ...
# 124  2019            37732257
# 125  2020            38693873
# 126  2021            39673487
# 127  2022            40671268
# 128  2023            41687386
#
# [129 rows x 2 columns]

# %%
import pandas as pd

# Ruta al archivo CSV en Google Drive
file_path = '/content/drive/MyDrive/Cancer de mama/SNEDH_SdR05a_FichaEvidencias.csv'

# Cargar el CSV en un DataFrame
df_SNEDH = pd.read_csv(file_path,skiprows=9)

# Ver las primeras filas del DataFrame
df_SNEDH
# Out:
#                 Cobertura geografica  Periodo  Tmcama  Defcama      Pfem
# 0           Estados Unidos Mexicanos     2010      16     5034  30844960
# 1                     Aguascalientes     2010      14       45    310718
# 2                    Baja California     2010      20      163    825760
# 3                Baja California Sur     2010      19       31    163749
# 4                           Campeche     2010      12       26    218399
# ..                               ...      ...     ...      ...       ...
# 391                       Tamaulipas     2021      28      300   1081715
# 392                         Tlaxcala     2021      12       48    404458
# 393  Veracruz de Ignacio de la Llave     2021      20      532   2603056
# 394                          Yucatán     2021      15      107    720832
# 395                        Zacatecas     2021      21       97    468697
#
# [396 rows x 5 columns]

# %%
# Contar cuántas veces aparece 'Estados Unidos Mexicanos' en la columna 'Cobertura geografica'
conteo_estados_unidos_mexicanos = df_SNEDH[df_SNEDH['Cobertura geografica'] == 'Estados Unidos Mexicanos'].shape[0]

# Mostrar el resultado
print(conteo_estados_unidos_mexicanos)
# Out:
# 12

# %%
# Filtrar las filas donde la columna 'Cobertura geografica' es 'Estados Unidos Mexicanos'
filas_estados_unidos_mexicanos = df_SNEDH[df_SNEDH['Cobertura geografica'] == 'Estados Unidos Mexicanos']

# Eliminar las columnas 'Cobertura geografica', 'Tmcama' y 'Defcama'
filas_estados_unidos_mexicanos = filas_estados_unidos_mexicanos.drop(columns=['Cobertura geografica', 'Tmcama', 'Defcama'])

# Renombrar la columna 'Periodo' a 'Año'
filas_estados_unidos_mexicanos = filas_estados_unidos_mexicanos.rename(columns={'Periodo': 'Año'})

# Reindexar para restablecer el índice
filas_estados_unidos_mexicanos = filas_estados_unidos_mexicanos.reset_index(drop=True)

# Mostrar las filas filtradas y modificadas
filas_estados_unidos_mexicanos
# Out:
#      Año      Pfem
# 0   2010  30844960
# 1   2011  31604691
# 2   2012  32362693
# 3   2013  33119331
# 4   2014  33873575
# 5   2015  34611681
# 6   2016  35344978
# 7   2017  36075493
# 8   2018  36797671
# 9   2019  37511160
# 10  2020  38325557
# 11  2021  38695271

# %%
import pandas as pd
ruta_guardado = '/content/drive/MyDrive/Cancer de mama/Tasa de mortalidad de 1990 - 2013 en mexico/mortalidad 90-16.csv'
df = pd.read_csv(ruta_guardado)
df
# Out:
#      Año  Defunciones por cáncer de mama en mujeres de 25 años o más  \
# 0   1990                                               4380
# 1   1991                                               4668
# 2   1992                                               5036
# 3   1993                                               5352
# 4   1994                                               5478
# 5   1995                                               5960
# 6   1996                                               6130
# 7   1997                                               6362
# 8   1998                                               6692
# 9   1999                                               6764
# 10  2000                                               6838
# 11  2001                                               7126
# 12  2002                                               7644
# 13  2003                                               7722
# ...

# %%
df_predictions
# Out:
#       Año  Población estimada
# 0    1895             2948882
# 1    1896             2988943
# 2    1897             3026038
# 3    1898             3060337
# 4    1899             3092009
# ..    ...                 ...
# 124  2019            37732257
# 125  2020            38693873
# 126  2021            39673487
# 127  2022            40671268
# 128  2023            41687386
#
# [129 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Asegúrate de que todos los DataFrames tienen la columna 'Año' y que los valores se alinean correctamente
# Para esto, primero nos aseguramos de que los DataFrames estén ordenados por 'Año'
df_SNEDH_sorted = filas_estados_unidos_mexicanos.sort_values(by="Año")
df_sorted = df.sort_values(by="Año")
df_predictions_sorted = df_predictions.sort_values(by="Año")

# Graficar los datos
plt.figure(figsize=(12, 6))

# Graficamos los datos para cada DataFrame
plt.plot(df_SNEDH_sorted["Año"], df_SNEDH_sorted["Pfem"], color="red", label="Datos SNEDH")
plt.plot(df_sorted["Año"], df_sorted["Población de mujeres de 25 años o más"], color="blue", label="Datos de la Secretaría de Salud")
plt.plot(df_predictions_sorted["Año"], df_predictions_sorted["Población estimada"], color="green", label="Censo de Población y Vivienda (Inegi)")

# Añadir etiquetas y título
plt.xlabel("Año")
plt.ylabel("Población")
#plt.title("Comparación de set de datos de la Población Femenina de 25 años o más en México")

# Añadir leyenda
plt.legend()

# Evitar notación científica en los ejes
formatter = FuncFormatter(lambda x, _: f'{x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)

# Mostrar la gráfica
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Verificar los años que abarca cada DataFrame
years_df_SNEDH = set(filas_estados_unidos_mexicanos['Año'])
years_df = set(df['Año'])
years_df_predictions = set(df_predictions['Año'])

# Encontrar los años comunes entre los tres DataFrames
common_years = sorted(years_df_SNEDH.intersection(years_df).intersection(years_df_predictions))

# Filtrar cada DataFrame para que solo contenga los años comunes
df_SNEDH_common = filas_estados_unidos_mexicanos[filas_estados_unidos_mexicanos['Año'].isin(common_years)]
df_common = df[df['Año'].isin(common_years)]
df_predictions_common = df_predictions[df_predictions['Año'].isin(common_years)]

# Crear un nuevo DataFrame que contenga solo los años comunes y las columnas necesarias
df_comparacion = pd.merge(df_SNEDH_common[['Año', 'Pfem']], df_common[['Año', 'Población de mujeres de 25 años o más']], on="Año", how="inner")
df_comparacion = pd.merge(df_comparacion, df_predictions_common[['Año', 'Población estimada']], on="Año", how="inner")

# Renombrar las columnas para mayor claridad
df_comparacion.columns = ["Año", "Pfem (Estados Unidos Mexicanos)", "Población de mujeres 25+ (df)", "Población estimada (df_predictions)"]

# Graficar los resultados
plt.figure(figsize=(12, 6))

# Graficar cada serie
plt.plot(df_comparacion["Año"], df_comparacion["Pfem (Estados Unidos Mexicanos)"], color="red", label="Datos SNEDH")
plt.plot(df_comparacion["Año"], df_comparacion["Población de mujeres 25+ (df)"], color="blue", label="Datos de la Secretaría de Salud")
plt.plot(df_comparacion["Año"], df_comparacion["Población estimada (df_predictions)"], color="green", label="Censo de Población y Vivienda (Inegi)")

# Añadir etiquetas y título
plt.xlabel("Año")
plt.ylabel("Población")
#plt.title("Comparación de intersección de la Población Femenina de 25 años o más en México")

# Añadir leyenda
plt.legend()

# Evitar notación científica en los ejes
formatter = FuncFormatter(lambda x, _: f'{x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)

# Mostrar la gráfica
plt.grid(True)
plt.show()

# Mostrar el DataFrame comparado
print(df_comparacion)
# Out:
#     Año  Pfem (Estados Unidos Mexicanos)  Población de mujeres 25+ (df)  \
# 0  2010                         30844960                       62304782
# 1  2011                         31604691                       63710053
# 2  2012                         32362693                       65116779
# 3  2013                         33119331                       66521317
# 4  2014                         33873575                       67935405
# 5  2015                         34611681                       69358429
# 6  2016                         35344978                       70783734
#
#    Población estimada (df_predictions)
# 0                             29859742
# 1                             30666981
# 2                             31490697
# 3                             32331058
# 4                             33188235
# 5                             34062395
# 6                             34953708

# %%
# Mostrar el DataFrame final
df_comparacion
# Out:
#     Año  Pfem (Estados Unidos Mexicanos)  Población de mujeres 25+ (df)  \
# 0  2010                         30844960                       62304782
# 1  2011                         31604691                       63710053
# 2  2012                         32362693                       65116779
# 3  2013                         33119331                       66521317
# 4  2014                         33873575                       67935405
# 5  2015                         34611681                       69358429
# 6  2016                         35344978                       70783734
#
#    Población estimada (df_predictions)
# 0                             29859742
# 1                             30666981
# 2                             31490697
# 3                             32331058
# 4                             33188235
# 5                             34062395
# 6                             34953708

# %%
# Filtrar los datos entre 2010 y 2016 en el DataFrame df_predictions
df_filtered = df[(df['Año'] >= 2010) & (df['Año'] <= 2016)]

# Mostrar el resultado filtrado
df_filtered
# Out:
#      Año  Defunciones por cáncer de mama en mujeres de 25 años o más  \
# 20  2010                                              10074
# 21  2011                                              10414
# 22  2012                                              11168
# 23  2013                                              11052
# 24  2014                                              11948
# 25  2015                                              12552
# 26  2016                                              13260
#
#     Población de mujeres de 25 años o más  \
# 20                               62304782
# 21                               63710053
# 22                               65116779
# 23                               66521317
# 24                               67935405
# 25                               69358429
# 26                               70783734
#
#     Tasa de mortalidad por cáncer de mama
# 20                                     16
# 21                                     16
# ...

# %%
import pandas as pd
ruta_guardado = '/content/drive/MyDrive/Cancer de mama/Tasa de mortalidad de 1990 - 2013 en mexico/mortalidad 90-16.csv'
df = pd.read_csv(ruta_guardado)
df
# Out:
#      Año  Defunciones por cáncer de mama en mujeres de 25 años o más  \
# 0   1990                                               4380
# 1   1991                                               4668
# 2   1992                                               5036
# 3   1993                                               5352
# 4   1994                                               5478
# 5   1995                                               5960
# 6   1996                                               6130
# 7   1997                                               6362
# 8   1998                                               6692
# 9   1999                                               6764
# 10  2000                                               6838
# 11  2001                                               7126
# 12  2002                                               7644
# 13  2003                                               7722
# ...

# %%
df_predictions
# Out:
#       Año  Población estimada
# 0    1895             2948882
# 1    1896             2988943
# 2    1897             3026038
# 3    1898             3060337
# 4    1899             3092009
# ..    ...                 ...
# 124  2019            37732257
# 125  2020            38693873
# 126  2021            39673487
# 127  2022            40671268
# 128  2023            41687386
#
# [129 rows x 2 columns]

# %%
# Filtrar el DataFrame para que incluya los años entre 1990 y 2016 (inclusive)
df_1990_onwards = df_predictions[(df_predictions['Año'] >= 1990) & (df_predictions['Año'] <= 2016)]

# Mostrar el DataFrame resultante
df_1990_onwards
# Out:
#       Año  Población estimada
# 95   1990            16914722
# 96   1991            17427929
# 97   1992            17954232
# 98   1993            18493799
# 99   1994            19046800
# 100  1995            19613404
# 101  1996            20193779
# 102  1997            20788095
# 103  1998            21396521
# 104  1999            22019226
# 105  2000            22656379
# 106  2001            23308149
# 107  2002            23974705
# 108  2003            24656217
# 109  2004            25352852
# 110  2005            26064781
# 111  2006            26792172
# 112  2007            27535195
# 113  2008            28294018
# 114  2009            29068811
# 115  2010            29859742
# 116  2011            30666981
# 117  2012            31490697
# 118  2013            32331058
# 119  2014            33188235
# 120  2015            34062395
# 121  2016            34953708

# %%
# Reindexa el DataFrame y elimina el índice anterior
df_1990_onwards = df_1990_onwards.reset_index(drop=True)
df_1990_onwards
# Out:
#      Año  Población estimada
# 0   1990            16914722
# 1   1991            17427929
# 2   1992            17954232
# 3   1993            18493799
# 4   1994            19046800
# 5   1995            19613404
# 6   1996            20193779
# 7   1997            20788095
# 8   1998            21396521
# 9   1999            22019226
# 10  2000            22656379
# 11  2001            23308149
# 12  2002            23974705
# 13  2003            24656217
# 14  2004            25352852
# 15  2005            26064781
# 16  2006            26792172
# 17  2007            27535195
# 18  2008            28294018
# 19  2009            29068811
# 20  2010            29859742
# 21  2011            30666981
# 22  2012            31490697
# 23  2013            32331058
# 24  2014            33188235
# 25  2015            34062395
# 26  2016            34953708

# %%
# Asegúrate de que los índices de ambos DataFrames estén alineados correctamente
df_1990_onwards['poblacion'] = df.loc[df_1990_onwards.index, 'Población de mujeres de 25 años o más']
df_1990_onwards
# Out:
#      Año  Población estimada  poblacion
# 0   1990            16914722   35852664
# 1   1991            17427929   37007840
# 2   1992            17954232   38193064
# 3   1993            18493799   39392350
# 4   1994            19046800   40623620
# 5   1995            19613404   41890024
# 6   1996            20193779   43182190
# 7   1997            20788095   44490494
# 8   1998            21396521   45816222
# 9   1999            22019226   47132266
# 10  2000            22656379   48432714
# 11  2001            23308149   49756872
# 12  2002            23974705   51131594
# 13  2003            24656217   52529180
# 14  2004            25352852   53906692
# 15  2005            26064781   55250834
# 16  2006            26792172   56601780
# 17  2007            27535195   57999644
# 18  2008            28294018   59435352
# 19  2009            29068811   60882268
# 20  2010            29859742   62304782
# 21  2011            30666981   63710053
# ...

# %%
# Calcular el porcentaje de aumento entre "Población estimada" y "población"
df_1990_onwards['Porcentaje aumento'] = df_1990_onwards.apply(
    lambda row: ((row['poblacion'] - row['Población estimada']) / row['Población estimada']) * 100 if row['Población estimada'] != 0 else np.inf, axis=1
)

# Calcular la diferencia entre "poblacion" y "Población estimada"
df_1990_onwards['Diferencia'] = df_1990_onwards['poblacion'] - df_1990_onwards['Población estimada']
df_1990_onwards
# Out:
#      Año  Población estimada  poblacion  Porcentaje aumento  Diferencia
# 0   1990            16914722   35852664                 112    18937942
# 1   1991            17427929   37007840                 112    19579911
# 2   1992            17954232   38193064                 113    20238832
# 3   1993            18493799   39392350                 113    20898551
# 4   1994            19046800   40623620                 113    21576820
# 5   1995            19613404   41890024                 114    22276620
# 6   1996            20193779   43182190                 114    22988411
# 7   1997            20788095   44490494                 114    23702399
# 8   1998            21396521   45816222                 114    24419701
# 9   1999            22019226   47132266                 114    25113040
# 10  2000            22656379   48432714                 114    25776335
# 11  2001            23308149   49756872                 113    26448723
# ...

# %%
df_1990_onwards.columns = ['Año', 'Población INEGI', 'Población Secretaría de salud', 'Diferencia', 'Porcentaje aumento']
df_1990_onwards
# Out:
#      Año  Población INEGI  Población Secretaría de salud  Diferencia  \
# 0   1990         16914722                       35852664    18937942
# 1   1991         17427929                       37007840    19579911
# 2   1992         17954232                       38193064    20238832
# 3   1993         18493799                       39392350    20898551
# 4   1994         19046800                       40623620    21576820
# 5   1995         19613404                       41890024    22276620
# 6   1996         20193779                       43182190    22988411
# 7   1997         20788095                       44490494    23702399
# 8   1998         21396521                       45816222    24419701
# 9   1999         22019226                       47132266    25113040
# 10  2000         22656379                       48432714    25776335
# 11  2001         23308149                       49756872    26448723
# 12  2002         23974705                       51131594    27156889
# ...

# %%
# Intercambiar las últimas dos columnas
df_1990_onwards[['Porcentaje aumento', 'Diferencia']] = df_1990_onwards[['Diferencia', 'Porcentaje aumento']]
df_1990_onwards
# Out:
#      Año  Población INEGI  Población Secretaría de salud  Porcentaje aumento  \
# 0   1990         16914722                       35852664            18937942
# 1   1991         17427929                       37007840            19579911
# 2   1992         17954232                       38193064            20238832
# 3   1993         18493799                       39392350            20898551
# 4   1994         19046800                       40623620            21576820
# 5   1995         19613404                       41890024            22276620
# 6   1996         20193779                       43182190            22988411
# 7   1997         20788095                       44490494            23702399
# 8   1998         21396521                       45816222            24419701
# 9   1999         22019226                       47132266            25113040
# 10  2000         22656379                       48432714            25776335
# ...

# %%
df_1990_onwards
# Out:
#      Año  Población INEGI  Población Secretaría de salud  Diferencia  \
# 0   1990         16914722                       35852664    18937942
# 1   1991         17427929                       37007840    19579911
# 2   1992         17954232                       38193064    20238832
# 3   1993         18493799                       39392350    20898551
# 4   1994         19046800                       40623620    21576820
# 5   1995         19613404                       41890024    22276620
# 6   1996         20193779                       43182190    22988411
# 7   1997         20788095                       44490494    23702399
# 8   1998         21396521                       45816222    24419701
# 9   1999         22019226                       47132266    25113040
# 10  2000         22656379                       48432714    25776335
# 11  2001         23308149                       49756872    26448723
# 12  2002         23974705                       51131594    27156889
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Crear una figura y ejes para graficar
fig, ax1 = plt.subplots(figsize=(10, 6))

# Graficar la Población INEGI
ax1.plot(df_1990_onwards['Año'], df_1990_onwards['Población INEGI'], color='tab:blue', label='Población INEGI', linestyle='-', marker='o')
ax1.set_xlabel('Año')
ax1.set_ylabel('Población INEGI', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Graficar la Población Secretaría de Salud
ax1.plot(df_1990_onwards['Año'], df_1990_onwards['Población Secretaría de salud'], color='tab:green', label='Población Secretaría de Salud', linestyle='-', marker='x')
ax1.set_ylabel('Población Secretaría de Salud', color='tab:green')
ax1.tick_params(axis='y', labelcolor='tab:green')

# Crear un segundo eje para graficar el porcentaje de aumento
ax2 = ax1.twinx()  # Crea un eje adicional con el mismo eje x
ax2.plot(df_1990_onwards['Año'], df_1990_onwards['Porcentaje aumento'], color='tab:red', label='Porcentaje aumento', linestyle='-.', marker='s')
ax2.set_ylabel('Porcentaje aumento', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Establecer los límites del eje y del porcentaje de aumento entre 0 y 120
ax2.set_ylim(0, 120)

# Desactivar notación científica
ax1.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{int(x):,}'))  # Población sin notación científica
ax2.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{int(x):,.0f}'))  # Porcentaje sin notación científica

# Agregar título y leyenda
plt.title('Población INEGI vs Población Secretaría de Salud y Porcentaje de Aumento')

# Mostrar leyenda
ax1.legend(loc='upper left')  # Leyenda para las poblaciones
ax2.legend(loc='upper right')  # Leyenda para el porcentaje de aumento

fig.tight_layout()  # Ajustar el layout para que no se solapen los ejes

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Crear una figura y ejes para graficar
fig, ax = plt.subplots(figsize=(10, 6))

# Definir el ancho de las barras
bar_width = 0.35

# Definir las posiciones en el eje X para las barras
index = range(len(df_1990_onwards['Año']))

# Graficar las barras para la Población INEGI
ax.bar(index, df_1990_onwards['Población INEGI'], bar_width, label='Población INEGI', color='tab:blue')

# Graficar las barras para la Población Secretaría de Salud, desplazada por un ancho de barra
ax.bar([i + bar_width for i in index], df_1990_onwards['Población Secretaría de salud'], bar_width, label='Población Secretaría de Salud', color='tab:green')

# Etiquetas de los ejes
ax.set_xlabel('Año')
ax.set_ylabel('Población')

# Ajustar las posiciones del eje X
ax.set_xticks([i + bar_width / 2 for i in index])  # Centrar las etiquetas de los años
ax.set_xticklabels(df_1990_onwards['Año'], rotation=45)

# Título
ax.set_title('Comparación de Población INEGI vs Población Secretaría de Salud')

# Leyenda
ax.legend()

# Mostrar gráfico
plt.tight_layout()  # Ajustar el layout para que no se solapen los elementos
plt.show()

# %%
df_predictions
# Out:
#       Año  Población estimada
# 0    1895             2948882
# 1    1896             2988943
# 2    1897             3026038
# 3    1898             3060337
# 4    1899             3092009
# ..    ...                 ...
# 124  2019            37732257
# 125  2020            38693873
# 126  2021            39673487
# 127  2022            40671268
# 128  2023            41687386
#
# [129 rows x 2 columns]

# %%
df_filtered = df_predictions[df_predictions['Año'] >= 2000].reset_index(drop=True)
df_filtered
# Out:
#      Año  Población estimada
# 0   2000            22656379
# 1   2001            23308149
# 2   2002            23974705
# 3   2003            24656217
# 4   2004            25352852
# 5   2005            26064781
# 6   2006            26792172
# 7   2007            27535195
# 8   2008            28294018
# 9   2009            29068811
# 10  2010            29859742
# 11  2011            30666981
# 12  2012            31490697
# 13  2013            32331058
# 14  2014            33188235
# 15  2015            34062395
# 16  2016            34953708
# 17  2017            35862344
# 18  2018            36788470
# 19  2019            37732257
# 20  2020            38693873
# 21  2021            39673487
# 22  2022            40671268
# 23  2023            41687386

# %%
# Crear un diccionario con los datos de defunciones
defunciones_data = {
    2000: 3419,
    2001: 3563,
    2002: 3822,
    2003: 3861,
    2004: 4150,
    2005: 4205,
    2006: 4440,
    2007: 4581,
    2008: 4802,
    2009: 4893,
    2010: 5034
}

# Agregar la columna de defunciones al DataFrame
df_filtered['Defunciones'] = df_filtered['Año'].map(defunciones_data)

# Mostrar el resultado
print(df_filtered)
# Out:
#      Año  Población estimada  Defunciones
# 0   2000            22656379         3419
# 1   2001            23308149         3563
# 2   2002            23974705         3822
# 3   2003            24656217         3861
# 4   2004            25352852         4150
# 5   2005            26064781         4205
# 6   2006            26792172         4440
# 7   2007            27535195         4581
# 8   2008            28294018         4802
# 9   2009            29068811         4893
# 10  2010            29859742         5034
# 11  2011            30666981          NaN
# 12  2012            31490697          NaN
# 13  2013            32331058          NaN
# 14  2014            33188235          NaN
# 15  2015            34062395          NaN
# 16  2016            34953708          NaN
# 17  2017            35862344          NaN
# 18  2018            36788470          NaN
# 19  2019            37732257          NaN
# 20  2020            38693873          NaN
# ...

# %%
# Diccionario adicional para defunciones de 2011 en adelante
defunciones_2011_data = {
    2011: 5206,
    2012: 5583,
    2013: 5526,
    2014: 5974,
    2015: 6252,
    2016: 6629,
    2017: 6814,
    2018: 7177,
    2019: 7461,
    2020: 7785,
    2021: 7873,
    2022: 7838,
    2023: 8034
}

# Añadir las nuevas defunciones al DataFrame
df_filtered['Defunciones'].update(df_filtered['Año'].map(defunciones_2011_data))

# Mostrar el DataFrame actualizado
print(df_filtered)
# Out:
#      Año  Población estimada  Defunciones
# 0   2000            22656379         3419
# 1   2001            23308149         3563
# 2   2002            23974705         3822
# 3   2003            24656217         3861
# 4   2004            25352852         4150
# 5   2005            26064781         4205
# 6   2006            26792172         4440
# 7   2007            27535195         4581
# 8   2008            28294018         4802
# 9   2009            29068811         4893
# 10  2010            29859742         5034
# 11  2011            30666981         5206
# 12  2012            31490697         5583
# 13  2013            32331058         5526
# 14  2014            33188235         5974
# 15  2015            34062395         6252
# 16  2016            34953708         6629
# 17  2017            35862344         6814
# 18  2018            36788470         7177
# 19  2019            37732257         7461
# 20  2020            38693873         7785
# ...

# %%
df_filtered
# Out:
#      Año  Población estimada  Defunciones
# 0   2000            22656379         3419
# 1   2001            23308149         3563
# 2   2002            23974705         3822
# 3   2003            24656217         3861
# 4   2004            25352852         4150
# 5   2005            26064781         4205
# 6   2006            26792172         4440
# 7   2007            27535195         4581
# 8   2008            28294018         4802
# 9   2009            29068811         4893
# 10  2010            29859742         5034
# 11  2011            30666981         5206
# 12  2012            31490697         5583
# 13  2013            32331058         5526
# 14  2014            33188235         5974
# 15  2015            34062395         6252
# 16  2016            34953708         6629
# 17  2017            35862344         6814
# 18  2018            36788470         7177
# 19  2019            37732257         7461
# 20  2020            38693873         7785
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, ScalarFormatter

# Función para formatear los valores de población en millones
def format_millions(x, pos):
    return f'{x:.1f}M'  # Mostrar en millones con un decimal

# Extraer los datos
años = df_filtered['Año']
poblacion = df_filtered['Población estimada']
defunciones = df_filtered['Defunciones']

# Crear la figura con dos subgráficas (uno para cada conjunto de datos)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))

# Graficar la población en la primera subgráfica
ax1.bar(años, poblacion / 1_000_000, label="Población estimada", color='blue', alpha=0.7)  # Dividir por 1 millón
ax1.set_title("Población Femenina de 25 Años o Más por Año")
ax1.set_xlabel("Año")
ax1.set_ylabel("Población estimada (millones)")
ax1.tick_params(axis='x', rotation=45)

# Aplicar el formateador para que los valores estén en millones
ax1.yaxis.set_major_formatter(FuncFormatter(format_millions))

# Graficar las defunciones en la segunda subgráfica
ax2.bar(años, defunciones, label="Defunciones", color='red', alpha=0.7)
ax2.set_title("Defunciones por Cáncer de Mama por Año")
ax2.set_xlabel("Año")
ax2.set_ylabel("Defunciones")
ax2.tick_params(axis='x', rotation=45)

# Desactivar la notación científica en el eje y de la segunda gráfica (defunciones)
ax2.yaxis.set_major_formatter(ScalarFormatter())
ax2.ticklabel_format(style='plain', axis='y')  # Asegura que no se use notación científica

# Ajustar el diseño para que no se sobrepongan las gráficas
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %%
# Verificar el tipo de dato de cada columna en df_filtered
print(df_filtered.dtypes)
# Out:
# Año                     int64
# Población estimada    float64
# Defunciones           float64
# dtype: object

# %%
df_filtered
# Out:
#      Año  Población estimada  Defunciones
# 0   2000            22656379         3419
# 1   2001            23308149         3563
# 2   2002            23974705         3822
# 3   2003            24656217         3861
# 4   2004            25352852         4150
# 5   2005            26064781         4205
# 6   2006            26792172         4440
# 7   2007            27535195         4581
# 8   2008            28294018         4802
# 9   2009            29068811         4893
# 10  2010            29859742         5034
# 11  2011            30666981         5206
# 12  2012            31490697         5583
# 13  2013            32331058         5526
# 14  2014            33188235         5974
# 15  2015            34062395         6252
# 16  2016            34953708         6629
# 17  2017            35862344         6814
# 18  2018            36788470         7177
# 19  2019            37732257         7461
# 20  2020            38693873         7785
# ...

# %%
# Crear la cuarta columna con el cálculo solicitado
df_filtered['Columna4'] = (df_filtered.iloc[:, 2] / df_filtered.iloc[:, 1]) * 100000

# Asegurarse de que los valores sean flotantes y tengan decimales
df_filtered['Columna4'] = df_filtered['Columna4'].apply(lambda x: round(x, 2))

# Verificar el resultado
print(df_filtered)
# Out:
#      Año  Población estimada  Defunciones  Columna4
# 0   2000            22656379         3419        15
# 1   2001            23308149         3563        15
# 2   2002            23974705         3822        16
# 3   2003            24656217         3861        16
# 4   2004            25352852         4150        16
# 5   2005            26064781         4205        16
# 6   2006            26792172         4440        17
# 7   2007            27535195         4581        17
# 8   2008            28294018         4802        17
# 9   2009            29068811         4893        17
# 10  2010            29859742         5034        17
# 11  2011            30666981         5206        17
# 12  2012            31490697         5583        18
# 13  2013            32331058         5526        17
# 14  2014            33188235         5974        18
# 15  2015            34062395         6252        18
# 16  2016            34953708         6629        19
# ...

# %%
# Especifica el nombre y la ubicación del archivo
file_path = '/content/drive/MyDrive/Cancer de mama/df_mujeres20002023.csv'

# Guarda el DataFrame como CSV
df_filtered.to_csv(file_path, index=False)

# Confirmar que el archivo fue guardado
print(f"El archivo CSV fue guardado en: {file_path}")
# Out:
# El archivo CSV fue guardado en: /content/drive/MyDrive/Cancer de mama/df_mujeres20002023.csv

# %%
df_predictions
# Out:
#       Año  Población estimada
# 0    1895             2948882
# 1    1896             2988943
# 2    1897             3026038
# 3    1898             3060337
# 4    1899             3092009
# ..    ...                 ...
# 124  2019            37732257
# 125  2020            38693873
# 126  2021            39673487
# 127  2022            40671268
# 128  2023            41687386
#
# [129 rows x 2 columns]

# %%
import pandas as pd
ruta_guardado = '/content/drive/MyDrive/Cancer de mama/Tasa de mortalidad de 1990 - 2013 en mexico/mortalidad 90-16.csv'
df = pd.read_csv(ruta_guardado)
df
# Out:
#      Año  Defunciones por cáncer de mama en mujeres de 25 años o más  \
# 0   1990                                               4380
# 1   1991                                               4668
# 2   1992                                               5036
# 3   1993                                               5352
# 4   1994                                               5478
# 5   1995                                               5960
# 6   1996                                               6130
# 7   1997                                               6362
# 8   1998                                               6692
# 9   1999                                               6764
# 10  2000                                               6838
# 11  2001                                               7126
# 12  2002                                               7644
# 13  2003                                               7722
# ...
